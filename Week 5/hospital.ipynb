# %%
import pandas as pd
# !pip install river
# Out:
# Unable to create process using 'C:\Users\This PC\anaconda3\python.exe "C:\Users\This PC\anaconda3\Scripts\pip-script.py" install river'

# %%
dataset = pd.read_csv("hospital_wait.csv")

# %%
dataset.head()
print(type(dataset))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
params = {'converters': {'value': float},'parse_dates': {'time': "%Y-%m-%d %H:%M:%S"}}

dataset = dict()
from river import stream
for x, y in stream.iter_csv('hospital_wait.csv', target = 'value', **params):
    print(x,y)
# Out:
# {'time': datetime.datetime(2022, 7, 28, 17, 11, 55)} 323.0
# {'time': datetime.datetime(2022, 7, 28, 17, 26, 56)} 323.0
# {'time': datetime.datetime(2022, 7, 28, 17, 41, 55)} 275.0
# {'time': datetime.datetime(2022, 7, 28, 17, 56, 56)} 275.0
# {'time': datetime.datetime(2022, 7, 28, 18, 11, 56)} 235.0
# {'time': datetime.datetime(2022, 7, 28, 18, 26, 56)} 235.0
# {'time': datetime.datetime(2022, 7, 28, 18, 41, 56)} 241.0
# {'time': datetime.datetime(2022, 7, 28, 18, 56, 59)} 241.0
# {'time': datetime.datetime(2022, 7, 28, 19, 11, 55)} 273.0
# {'time': datetime.datetime(2022, 7, 28, 19, 26, 56)} 273.0
# {'time': datetime.datetime(2022, 7, 28, 19, 41, 56)} 241.0
# {'time': datetime.datetime(2022, 7, 28, 19, 56, 55)} 241.0
# {'time': datetime.datetime(2022, 7, 28, 20, 11, 55)} 221.0
# {'time': datetime.datetime(2022, 7, 28, 20, 26, 56)} 221.0
# {'time': datetime.datetime(2022, 7, 28, 20, 41, 56)} 288.0
# {'time': datetime.datetime(2022, 7, 28, 20, 56, 55)} 288.0
# {'time': datetime.datetime(2022, 7, 28, 21, 11, 56)} 243.0
# {'time': datetime.datetime(2022, 7, 28, 21, 26, 55)} 243.0
# {'time': datetime.datetime(2022, 7, 28, 21, 41, 55)} 204.0
# {'time': datetime.datetime(2022, 7, 28, 21, 56, 55)} 204.0
# {'time': datetime.datetime(2022, 7, 28, 22, 11, 55)} 201.0
# {'time': datetime.datetime(2022, 7, 28, 22, 26, 56)} 201.0
# {'time': datetime.datetime(2022, 7, 28, 22, 41, 56)} 261.0
# {'time': datetime.datetime(2022, 7, 28, 22, 56, 56)} 261.0
# {'time': datetime.datetime(2022, 7, 28, 23, 11, 55)} 157.0
# {'time': datetime.datetime(2022, 7, 28, 23, 26, 56)} 157.0
# {'time': datetime.datetime(2022, 7, 28, 23, 41, 55)} 163.0
# {'time': datetime.datetime(2022, 7, 28, 23, 56, 56)} 163.0
# {'time': datetime.datetime(2022, 7, 29, 0, 11, 55)} 143.0
# {'time': datetime.datetime(2022, 7, 29, 0, 26, 56)} 143.0
# {'time': datetime.datetime(2022, 7, 29, 0, 41, 55)} 136.0
# {'time': datetime.datetime(2022, 7, 29, 0, 56, 55)} 136.0
# {'time': datetime.datetime(2022, 7, 29, 1, 11, 56)} 133.0
# {'time': datetime.datetime(2022, 7, 29, 1, 26, 55)} 133.0
# {'time': datetime.datetime(2022, 7, 29, 1, 41, 55)} 113.0
# {'time': datetime.datetime(2022, 7, 29, 1, 56, 55)} 113.0
# {'time': datetime.datetime(2022, 7, 29, 2, 11, 55)} 107.0
# {'time': datetime.datetime(2022, 7, 29, 2, 26, 56)} 107.0
# {'time': datetime.datetime(2022, 7, 29, 2, 41, 56)} 72.0
# {'time': datetime.datetime(2022, 7, 29, 2, 56, 56)} 72.0
# {'time': datetime.datetime(2022, 7, 29, 3, 11, 55)} 59.0
# {'time': datetime.datetime(2022, 7, 29, 3, 26, 55)} 59.0
# {'time': datetime.datetime(2022, 7, 29, 3, 41, 55)} 61.0
# {'time': datetime.datetime(2022, 7, 29, 3, 56, 55)} 61.0
# {'time': datetime.datetime(2022, 7, 29, 4, 11, 56)} 121.0
# {'time': datetime.datetime(2022, 7, 29, 4, 26, 57)} 202.0
# {'time': datetime.datetime(2022, 7, 29, 4, 41, 56)} 202.0
# {'time': datetime.datetime(2022, 7, 29, 4, 56, 56)} 202.0
# {'time': datetime.datetime(2022, 7, 29, 5, 11, 56)} 276.0
# {'time': datetime.datetime(2022, 7, 29, 5, 26, 55)} 276.0
# {'time': datetime.datetime(2022, 7, 29, 5, 41, 55)} 233.0
# {'time': datetime.datetime(2022, 7, 29, 5, 56, 55)} 233.0
# {'time': datetime.datetime(2022, 7, 29, 6, 11, 55)} 275.0
# {'time': datetime.datetime(2022, 7, 29, 6, 26, 56)} 275.0
# {'time': datetime.datetime(2022, 7, 29, 6, 41, 56)} 454.0
# {'time': datetime.datetime(2022, 7, 29, 6, 56, 56)} 454.0
# {'time': datetime.datetime(2022, 7, 29, 7, 11, 56)} 570.0
# {'time': datetime.datetime(2022, 7, 29, 7, 26, 55)} 570.0
# {'time': datetime.datetime(2022, 7, 29, 7, 41, 55)} 461.0
# {'time': datetime.datetime(2022, 7, 29, 7, 56, 56)} 461.0
# {'time': datetime.datetime(2022, 7, 29, 8, 11, 55)} 420.0
# {'time': datetime.datetime(2022, 7, 29, 8, 26, 56)} 420.0
# {'time': datetime.datetime(2022, 7, 29, 8, 41, 55)} 454.0
# {'time': datetime.datetime(2022, 7, 29, 8, 56, 55)} 454.0
# {'time': datetime.datetime(2022, 7, 29, 9, 11, 56)} 325.0
# {'time': datetime.datetime(2022, 7, 29, 9, 26, 55)} 325.0
# {'time': datetime.datetime(2022, 7, 29, 9, 41, 56)} 305.0
# {'time': datetime.datetime(2022, 7, 29, 9, 56, 55)} 305.0
# {'time': datetime.datetime(2022, 7, 29, 10, 11, 56)} 443.0
# {'time': datetime.datetime(2022, 7, 29, 10, 26, 55)} 443.0
# {'time': datetime.datetime(2022, 7, 29, 10, 41, 56)} 427.0
# {'time': datetime.datetime(2022, 7, 29, 10, 56, 57)} 427.0
# {'time': datetime.datetime(2022, 7, 29, 11, 11, 56)} 296.0
# {'time': datetime.datetime(2022, 7, 29, 11, 26, 55)} 296.0
# {'time': datetime.datetime(2022, 7, 29, 11, 41, 56)} 290.0
# {'time': datetime.datetime(2022, 7, 29, 11, 56, 56)} 290.0
# {'time': datetime.datetime(2022, 7, 29, 12, 11, 56)} 277.0
# {'time': datetime.datetime(2022, 7, 29, 12, 26, 56)} 250.0
# {'time': datetime.datetime(2022, 7, 29, 12, 41, 55)} 250.0
# {'time': datetime.datetime(2022, 7, 29, 12, 56, 56)} 250.0
# {'time': datetime.datetime(2022, 7, 29, 13, 11, 56)} 216.0
# {'time': datetime.datetime(2022, 7, 29, 13, 26, 55)} 216.0
# {'time': datetime.datetime(2022, 7, 29, 13, 41, 56)} 239.0
# {'time': datetime.datetime(2022, 7, 29, 13, 56, 56)} 239.0
# {'time': datetime.datetime(2022, 7, 29, 14, 11, 56)} 251.0
# {'time': datetime.datetime(2022, 7, 29, 14, 26, 56)} 231.0
# {'time': datetime.datetime(2022, 7, 29, 14, 41, 56)} 231.0
# {'time': datetime.datetime(2022, 7, 29, 14, 56, 55)} 231.0
# {'time': datetime.datetime(2022, 7, 29, 15, 11, 56)} 247.0
# {'time': datetime.datetime(2022, 7, 29, 15, 26, 55)} 247.0
# {'time': datetime.datetime(2022, 7, 29, 15, 41, 55)} 296.0
# {'time': datetime.datetime(2022, 7, 29, 15, 56, 56)} 296.0
# {'time': datetime.datetime(2022, 7, 29, 16, 11, 55)} 292.0
# {'time': datetime.datetime(2022, 7, 29, 16, 26, 55)} 292.0
# {'time': datetime.datetime(2022, 7, 29, 16, 41, 55)} 377.0
# {'time': datetime.datetime(2022, 7, 29, 16, 56, 56)} 377.0
# {'time': datetime.datetime(2022, 7, 29, 17, 11, 56)} 357.0
# {'time': datetime.datetime(2022, 7, 29, 17, 26, 56)} 357.0
# {'time': datetime.datetime(2022, 7, 29, 17, 41, 56)} 340.0
# {'time': datetime.datetime(2022, 7, 29, 17, 56, 55)} 340.0
# {'time': datetime.datetime(2022, 7, 29, 18, 11, 56)} 316.0
# {'time': datetime.datetime(2022, 7, 29, 18, 26, 56)} 316.0
# {'time': datetime.datetime(2022, 7, 29, 18, 41, 55)} 301.0
# {'time': datetime.datetime(2022, 7, 29, 18, 56, 55)} 301.0
# {'time': datetime.datetime(2022, 7, 29, 19, 11, 57)} 220.0
# {'time': datetime.datetime(2022, 7, 29, 19, 26, 56)} 220.0
# {'time': datetime.datetime(2022, 7, 29, 19, 41, 55)} 191.0
# {'time': datetime.datetime(2022, 7, 29, 19, 56, 56)} 189.0
# {'time': datetime.datetime(2022, 7, 29, 20, 11, 55)} 189.0
# {'time': datetime.datetime(2022, 7, 29, 20, 26, 56)} 189.0
# {'time': datetime.datetime(2022, 7, 29, 20, 41, 55)} 173.0
# {'time': datetime.datetime(2022, 7, 29, 20, 56, 56)} 173.0
# {'time': datetime.datetime(2022, 7, 29, 21, 11, 55)} 145.0
# {'time': datetime.datetime(2022, 7, 29, 21, 26, 55)} 145.0
# {'time': datetime.datetime(2022, 7, 29, 21, 41, 56)} 161.0
# {'time': datetime.datetime(2022, 7, 29, 21, 56, 56)} 161.0
# {'time': datetime.datetime(2022, 7, 29, 22, 11, 56)} 188.0
# {'time': datetime.datetime(2022, 7, 29, 22, 26, 56)} 188.0
# {'time': datetime.datetime(2022, 7, 29, 22, 41, 56)} 179.0
# {'time': datetime.datetime(2022, 7, 29, 22, 56, 56)} 179.0
# {'time': datetime.datetime(2022, 7, 29, 23, 11, 56)} 158.0
# {'time': datetime.datetime(2022, 7, 29, 23, 26, 56)} 158.0
# {'time': datetime.datetime(2022, 7, 29, 23, 41, 55)} 135.0
# {'time': datetime.datetime(2022, 7, 29, 23, 56, 56)} 135.0
# {'time': datetime.datetime(2022, 7, 30, 0, 11, 56)} 150.0
# {'time': datetime.datetime(2022, 7, 30, 0, 26, 56)} 150.0
# {'time': datetime.datetime(2022, 7, 30, 0, 41, 55)} 148.0
# {'time': datetime.datetime(2022, 7, 30, 0, 56, 56)} 148.0
# {'time': datetime.datetime(2022, 7, 30, 1, 11, 55)} 112.0
# {'time': datetime.datetime(2022, 7, 30, 1, 26, 56)} 112.0
# {'time': datetime.datetime(2022, 7, 30, 1, 41, 55)} 82.0
# {'time': datetime.datetime(2022, 7, 30, 1, 56, 56)} 82.0
# {'time': datetime.datetime(2022, 7, 30, 2, 11, 55)} 78.0
# {'time': datetime.datetime(2022, 7, 30, 2, 26, 56)} 78.0
# {'time': datetime.datetime(2022, 7, 30, 2, 41, 55)} 69.0
# {'time': datetime.datetime(2022, 7, 30, 2, 56, 55)} 69.0
# {'time': datetime.datetime(2022, 7, 30, 3, 11, 55)} 48.0
# {'time': datetime.datetime(2022, 7, 30, 3, 26, 55)} 48.0
# {'time': datetime.datetime(2022, 7, 30, 3, 41, 56)} 34.0
# {'time': datetime.datetime(2022, 7, 30, 3, 56, 56)} 34.0
# {'time': datetime.datetime(2022, 7, 30, 4, 11, 55)} 23.0
# {'time': datetime.datetime(2022, 7, 30, 4, 26, 55)} 23.0
# {'time': datetime.datetime(2022, 7, 30, 4, 41, 55)} 22.0
# {'time': datetime.datetime(2022, 7, 30, 4, 56, 55)} 34.0
# {'time': datetime.datetime(2022, 7, 30, 5, 11, 55)} 34.0
# {'time': datetime.datetime(2022, 7, 30, 5, 26, 56)} 34.0
# {'time': datetime.datetime(2022, 7, 30, 5, 41, 56)} 68.0
# {'time': datetime.datetime(2022, 7, 30, 5, 56, 56)} 68.0
# {'time': datetime.datetime(2022, 7, 30, 6, 11, 55)} 69.0
# {'time': datetime.datetime(2022, 7, 30, 6, 26, 55)} 69.0
# {'time': datetime.datetime(2022, 7, 30, 6, 41, 55)} 115.0
# {'time': datetime.datetime(2022, 7, 30, 6, 56, 55)} 115.0
# {'time': datetime.datetime(2022, 7, 30, 7, 11, 55)} 184.0
# {'time': datetime.datetime(2022, 7, 30, 7, 26, 56)} 184.0
# {'time': datetime.datetime(2022, 7, 30, 7, 41, 56)} 235.0
# {'time': datetime.datetime(2022, 7, 30, 7, 56, 55)} 235.0
# {'time': datetime.datetime(2022, 7, 30, 8, 11, 56)} 252.0
# {'time': datetime.datetime(2022, 7, 30, 8, 26, 55)} 252.0
# {'time': datetime.datetime(2022, 7, 30, 8, 41, 55)} 274.0
# {'time': datetime.datetime(2022, 7, 30, 8, 56, 56)} 274.0
# {'time': datetime.datetime(2022, 7, 30, 9, 11, 55)} 283.0
# {'time': datetime.datetime(2022, 7, 30, 9, 26, 55)} 283.0
# {'time': datetime.datetime(2022, 7, 30, 9, 41, 55)} 282.0
# {'time': datetime.datetime(2022, 7, 30, 9, 56, 55)} 282.0
# {'time': datetime.datetime(2022, 7, 30, 10, 11, 56)} 299.0
# {'time': datetime.datetime(2022, 7, 30, 10, 26, 55)} 299.0
# {'time': datetime.datetime(2022, 7, 30, 10, 41, 55)} 306.0
# {'time': datetime.datetime(2022, 7, 30, 10, 56, 55)} 306.0
# {'time': datetime.datetime(2022, 7, 30, 11, 11, 55)} 300.0
# {'time': datetime.datetime(2022, 7, 30, 11, 26, 55)} 300.0
# {'time': datetime.datetime(2022, 7, 30, 11, 41, 55)} 309.0
# {'time': datetime.datetime(2022, 7, 30, 11, 56, 56)} 309.0
# {'time': datetime.datetime(2022, 7, 30, 12, 11, 55)} 308.0
# {'time': datetime.datetime(2022, 7, 30, 12, 26, 55)} 381.0
# {'time': datetime.datetime(2022, 7, 30, 12, 41, 56)} 381.0
# {'time': datetime.datetime(2022, 7, 30, 12, 56, 55)} 381.0
# {'time': datetime.datetime(2022, 7, 30, 13, 11, 56)} 313.0
# {'time': datetime.datetime(2022, 7, 30, 13, 26, 55)} 313.0
# {'time': datetime.datetime(2022, 7, 30, 13, 41, 55)} 303.0
# {'time': datetime.datetime(2022, 7, 30, 13, 56, 55)} 303.0
# {'time': datetime.datetime(2022, 7, 30, 14, 11, 56)} 370.0
# {'time': datetime.datetime(2022, 7, 30, 14, 26, 55)} 370.0
# {'time': datetime.datetime(2022, 7, 30, 14, 41, 55)} 301.0
# {'time': datetime.datetime(2022, 7, 30, 14, 56, 55)} 301.0
# {'time': datetime.datetime(2022, 7, 30, 15, 11, 55)} 282.0
# {'time': datetime.datetime(2022, 7, 30, 15, 26, 55)} 282.0
# {'time': datetime.datetime(2022, 7, 30, 15, 41, 55)} 281.0
# {'time': datetime.datetime(2022, 7, 30, 15, 56, 55)} 281.0
# {'time': datetime.datetime(2022, 7, 30, 16, 11, 55)} 280.0
# {'time': datetime.datetime(2022, 7, 30, 16, 26, 55)} 280.0
# {'time': datetime.datetime(2022, 7, 30, 16, 41, 55)} 394.0
# {'time': datetime.datetime(2022, 7, 30, 16, 56, 55)} 394.0
# {'time': datetime.datetime(2022, 7, 30, 17, 11, 56)} 402.0
# {'time': datetime.datetime(2022, 7, 30, 17, 26, 56)} 402.0
# {'time': datetime.datetime(2022, 7, 30, 17, 41, 55)} 195.0
# {'time': datetime.datetime(2022, 7, 30, 17, 56, 56)} 195.0
# {'time': datetime.datetime(2022, 7, 30, 18, 11, 55)} 228.0
# {'time': datetime.datetime(2022, 7, 30, 18, 26, 56)} 228.0
# {'time': datetime.datetime(2022, 7, 30, 18, 41, 56)} 250.0
# {'time': datetime.datetime(2022, 7, 30, 18, 56, 56)} 250.0
# {'time': datetime.datetime(2022, 7, 30, 19, 11, 55)} 251.0
# {'time': datetime.datetime(2022, 7, 30, 19, 26, 56)} 251.0
# {'time': datetime.datetime(2022, 7, 30, 19, 41, 56)} 247.0
# {'time': datetime.datetime(2022, 7, 30, 19, 56, 55)} 247.0
# {'time': datetime.datetime(2022, 7, 30, 20, 11, 56)} 223.0
# {'time': datetime.datetime(2022, 7, 30, 20, 26, 55)} 223.0
# {'time': datetime.datetime(2022, 7, 30, 20, 41, 56)} 253.0
# {'time': datetime.datetime(2022, 7, 30, 20, 56, 55)} 253.0
# {'time': datetime.datetime(2022, 7, 30, 21, 11, 56)} 258.0
# {'time': datetime.datetime(2022, 7, 30, 21, 26, 55)} 258.0
# {'time': datetime.datetime(2022, 7, 30, 21, 41, 56)} 215.0
# {'time': datetime.datetime(2022, 7, 30, 21, 56, 55)} 215.0
# {'time': datetime.datetime(2022, 7, 30, 22, 11, 55)} 244.0
# {'time': datetime.datetime(2022, 7, 30, 22, 26, 55)} 207.0
# {'time': datetime.datetime(2022, 7, 30, 22, 41, 55)} 207.0
# {'time': datetime.datetime(2022, 7, 30, 22, 56, 55)} 207.0
# {'time': datetime.datetime(2022, 7, 30, 23, 11, 56)} 184.0
# {'time': datetime.datetime(2022, 7, 30, 23, 26, 56)} 184.0
# {'time': datetime.datetime(2022, 7, 30, 23, 41, 56)} 168.0
# {'time': datetime.datetime(2022, 7, 30, 23, 56, 56)} 168.0
# {'time': datetime.datetime(2022, 7, 31, 0, 11, 56)} 136.0
# {'time': datetime.datetime(2022, 7, 31, 0, 26, 56)} 125.0
# {'time': datetime.datetime(2022, 7, 31, 0, 41, 55)} 125.0
# {'time': datetime.datetime(2022, 7, 31, 0, 56, 56)} 125.0
# {'time': datetime.datetime(2022, 7, 31, 1, 11, 56)} 112.0
# {'time': datetime.datetime(2022, 7, 31, 1, 26, 55)} 112.0
# {'time': datetime.datetime(2022, 7, 31, 1, 41, 55)} 132.0
# {'time': datetime.datetime(2022, 7, 31, 1, 56, 56)} 132.0
# {'time': datetime.datetime(2022, 7, 31, 2, 11, 56)} 118.0
# {'time': datetime.datetime(2022, 7, 31, 2, 26, 55)} 118.0
# {'time': datetime.datetime(2022, 7, 31, 2, 41, 55)} 102.0
# {'time': datetime.datetime(2022, 7, 31, 2, 56, 56)} 102.0
# {'time': datetime.datetime(2022, 7, 31, 3, 11, 55)} 101.0
# {'time': datetime.datetime(2022, 7, 31, 3, 26, 56)} 101.0
# {'time': datetime.datetime(2022, 7, 31, 3, 41, 56)} 85.0
# {'time': datetime.datetime(2022, 7, 31, 3, 56, 55)} 85.0
# {'time': datetime.datetime(2022, 7, 31, 4, 11, 56)} 86.0
# {'time': datetime.datetime(2022, 7, 31, 4, 26, 55)} 86.0
# {'time': datetime.datetime(2022, 7, 31, 4, 41, 56)} 97.0
# {'time': datetime.datetime(2022, 7, 31, 4, 56, 55)} 97.0
# {'time': datetime.datetime(2022, 7, 31, 5, 11, 55)} 112.0
# {'time': datetime.datetime(2022, 7, 31, 5, 26, 56)} 112.0
# {'time': datetime.datetime(2022, 7, 31, 5, 41, 56)} 101.0
# {'time': datetime.datetime(2022, 7, 31, 5, 56, 55)} 101.0
# {'time': datetime.datetime(2022, 7, 31, 6, 11, 55)} 90.0
# {'time': datetime.datetime(2022, 7, 31, 6, 26, 55)} 90.0
# {'time': datetime.datetime(2022, 7, 31, 6, 41, 55)} 160.0
# {'time': datetime.datetime(2022, 7, 31, 6, 56, 55)} 160.0
# {'time': datetime.datetime(2022, 7, 31, 7, 11, 55)} 254.0
# {'time': datetime.datetime(2022, 7, 31, 7, 26, 56)} 254.0
# {'time': datetime.datetime(2022, 7, 31, 7, 41, 56)} 340.0
# {'time': datetime.datetime(2022, 7, 31, 7, 56, 55)} 340.0
# {'time': datetime.datetime(2022, 7, 31, 8, 11, 56)} 267.0
# {'time': datetime.datetime(2022, 7, 31, 8, 26, 55)} 267.0
# {'time': datetime.datetime(2022, 7, 31, 8, 41, 55)} 240.0
# {'time': datetime.datetime(2022, 7, 31, 8, 56, 55)} 240.0
# {'time': datetime.datetime(2022, 7, 31, 9, 11, 55)} 213.0
# {'time': datetime.datetime(2022, 7, 31, 9, 26, 56)} 213.0
# {'time': datetime.datetime(2022, 7, 31, 9, 41, 56)} 262.0
# {'time': datetime.datetime(2022, 7, 31, 9, 56, 55)} 262.0
# {'time': datetime.datetime(2022, 7, 31, 10, 11, 55)} 267.0
# {'time': datetime.datetime(2022, 7, 31, 10, 26, 55)} 267.0
# {'time': datetime.datetime(2022, 7, 31, 10, 41, 55)} 433.0
# {'time': datetime.datetime(2022, 7, 31, 10, 56, 55)} 433.0
# {'time': datetime.datetime(2022, 7, 31, 11, 11, 56)} 373.0
# {'time': datetime.datetime(2022, 7, 31, 11, 26, 56)} 373.0
# {'time': datetime.datetime(2022, 7, 31, 11, 41, 56)} 320.0
# {'time': datetime.datetime(2022, 7, 31, 11, 56, 56)} 320.0
# {'time': datetime.datetime(2022, 7, 31, 12, 11, 56)} 311.0
# {'time': datetime.datetime(2022, 7, 31, 12, 26, 55)} 311.0
# {'time': datetime.datetime(2022, 7, 31, 12, 41, 56)} 176.0
# {'time': datetime.datetime(2022, 7, 31, 12, 56, 55)} 176.0
# {'time': datetime.datetime(2022, 7, 31, 13, 11, 55)} 155.0
# {'time': datetime.datetime(2022, 7, 31, 13, 26, 56)} 155.0
# {'time': datetime.datetime(2022, 7, 31, 13, 41, 56)} 237.0
# {'time': datetime.datetime(2022, 7, 31, 13, 56, 55)} 237.0
# {'time': datetime.datetime(2022, 7, 31, 14, 11, 56)} 196.0
# {'time': datetime.datetime(2022, 7, 31, 14, 26, 55)} 196.0
# {'time': datetime.datetime(2022, 7, 31, 14, 41, 56)} 175.0
# {'time': datetime.datetime(2022, 7, 31, 14, 56, 55)} 175.0
# {'time': datetime.datetime(2022, 7, 31, 15, 11, 55)} 191.0
# {'time': datetime.datetime(2022, 7, 31, 15, 26, 55)} 191.0
# {'time': datetime.datetime(2022, 7, 31, 15, 41, 55)} 124.0
# {'time': datetime.datetime(2022, 7, 31, 15, 56, 55)} 124.0
# {'time': datetime.datetime(2022, 7, 31, 16, 11, 56)} 111.0
# {'time': datetime.datetime(2022, 7, 31, 16, 26, 55)} 111.0
# {'time': datetime.datetime(2022, 7, 31, 16, 41, 56)} 75.0
# {'time': datetime.datetime(2022, 7, 31, 16, 56, 56)} 75.0
# {'time': datetime.datetime(2022, 7, 31, 17, 11, 55)} 79.0
# {'time': datetime.datetime(2022, 7, 31, 17, 26, 55)} 79.0
# {'time': datetime.datetime(2022, 7, 31, 17, 41, 55)} 44.0
# {'time': datetime.datetime(2022, 7, 31, 17, 56, 55)} 44.0
# {'time': datetime.datetime(2022, 7, 31, 18, 11, 55)} 33.0
# {'time': datetime.datetime(2022, 7, 31, 18, 26, 55)} 33.0
# {'time': datetime.datetime(2022, 7, 31, 18, 41, 55)} 28.0
# {'time': datetime.datetime(2022, 7, 31, 18, 56, 56)} 28.0
# {'time': datetime.datetime(2022, 7, 31, 19, 11, 55)} 16.0
# {'time': datetime.datetime(2022, 7, 31, 19, 26, 55)} 16.0
# {'time': datetime.datetime(2022, 7, 31, 19, 41, 55)} 19.0
# {'time': datetime.datetime(2022, 7, 31, 19, 56, 55)} 19.0
# {'time': datetime.datetime(2022, 7, 31, 20, 11, 55)} 24.0
# {'time': datetime.datetime(2022, 7, 31, 20, 26, 55)} 24.0
# {'time': datetime.datetime(2022, 7, 31, 20, 41, 55)} 16.0
# {'time': datetime.datetime(2022, 7, 31, 20, 56, 55)} 16.0
# {'time': datetime.datetime(2022, 7, 31, 21, 11, 56)} 11.0
# {'time': datetime.datetime(2022, 7, 31, 21, 26, 56)} 11.0
# {'time': datetime.datetime(2022, 7, 31, 21, 41, 55)} 13.0
# {'time': datetime.datetime(2022, 7, 31, 21, 56, 55)} 13.0
# {'time': datetime.datetime(2022, 7, 31, 22, 11, 56)} 42.0
# {'time': datetime.datetime(2022, 7, 31, 22, 26, 56)} 42.0
# {'time': datetime.datetime(2022, 7, 31, 22, 41, 56)} 56.0
# {'time': datetime.datetime(2022, 7, 31, 22, 56, 55)} 56.0
# {'time': datetime.datetime(2022, 7, 31, 23, 11, 56)} 62.0
# {'time': datetime.datetime(2022, 7, 31, 23, 26, 55)} 62.0
# {'time': datetime.datetime(2022, 7, 31, 23, 41, 55)} 51.0
# {'time': datetime.datetime(2022, 7, 31, 23, 56, 56)} 51.0
# {'time': datetime.datetime(2022, 8, 1, 0, 11, 55)} 38.0
# {'time': datetime.datetime(2022, 8, 1, 0, 26, 55)} 38.0
# {'time': datetime.datetime(2022, 8, 1, 0, 41, 56)} 37.0
# {'time': datetime.datetime(2022, 8, 1, 0, 56, 55)} 37.0
# {'time': datetime.datetime(2022, 8, 1, 1, 11, 56)} 58.0
# {'time': datetime.datetime(2022, 8, 1, 1, 26, 56)} 58.0
# {'time': datetime.datetime(2022, 8, 1, 1, 41, 55)} 55.0
# {'time': datetime.datetime(2022, 8, 1, 1, 56, 55)} 55.0
# {'time': datetime.datetime(2022, 8, 1, 2, 11, 55)} 51.0
# {'time': datetime.datetime(2022, 8, 1, 2, 26, 55)} 45.0
# {'time': datetime.datetime(2022, 8, 1, 2, 41, 56)} 45.0
# {'time': datetime.datetime(2022, 8, 1, 2, 56, 55)} 45.0
# {'time': datetime.datetime(2022, 8, 1, 3, 11, 55)} 40.0
# {'time': datetime.datetime(2022, 8, 1, 3, 26, 56)} 40.0
# {'time': datetime.datetime(2022, 8, 1, 3, 41, 55)} 38.0
# {'time': datetime.datetime(2022, 8, 1, 3, 56, 55)} 38.0
# {'time': datetime.datetime(2022, 8, 1, 4, 11, 55)} 29.0
# {'time': datetime.datetime(2022, 8, 1, 4, 26, 55)} 29.0
# {'time': datetime.datetime(2022, 8, 1, 4, 41, 55)} 35.0
# {'time': datetime.datetime(2022, 8, 1, 4, 56, 56)} 35.0
# {'time': datetime.datetime(2022, 8, 1, 5, 11, 55)} 42.0
# {'time': datetime.datetime(2022, 8, 1, 5, 26, 56)} 42.0
# {'time': datetime.datetime(2022, 8, 1, 5, 41, 55)} 48.0
# {'time': datetime.datetime(2022, 8, 1, 5, 56, 55)} 48.0
# {'time': datetime.datetime(2022, 8, 1, 6, 11, 56)} 57.0
# {'time': datetime.datetime(2022, 8, 1, 6, 26, 55)} 57.0
# {'time': datetime.datetime(2022, 8, 1, 6, 41, 55)} 60.0
# {'time': datetime.datetime(2022, 8, 1, 6, 56, 55)} 60.0
# {'time': datetime.datetime(2022, 8, 1, 7, 11, 55)} 65.0
# {'time': datetime.datetime(2022, 8, 1, 7, 26, 55)} 65.0
# {'time': datetime.datetime(2022, 8, 1, 7, 41, 55)} 222.0
# {'time': datetime.datetime(2022, 8, 1, 7, 56, 55)} 291.0
# {'time': datetime.datetime(2022, 8, 1, 8, 11, 56)} 291.0
# {'time': datetime.datetime(2022, 8, 1, 8, 26, 55)} 291.0
# {'time': datetime.datetime(2022, 8, 1, 8, 41, 56)} 391.0
# {'time': datetime.datetime(2022, 8, 1, 8, 56, 56)} 391.0
# {'time': datetime.datetime(2022, 8, 1, 9, 11, 55)} 357.0
# {'time': datetime.datetime(2022, 8, 1, 9, 26, 56)} 357.0
# {'time': datetime.datetime(2022, 8, 1, 9, 41, 56)} 375.0
# {'time': datetime.datetime(2022, 8, 1, 9, 56, 55)} 375.0
# {'time': datetime.datetime(2022, 8, 1, 10, 11, 56)} 343.0
# {'time': datetime.datetime(2022, 8, 1, 10, 26, 56)} 334.0
# {'time': datetime.datetime(2022, 8, 1, 10, 41, 55)} 334.0
# {'time': datetime.datetime(2022, 8, 1, 10, 56, 56)} 334.0
# {'time': datetime.datetime(2022, 8, 1, 11, 11, 55)} 301.0
# {'time': datetime.datetime(2022, 8, 1, 11, 26, 55)} 301.0
# {'time': datetime.datetime(2022, 8, 1, 11, 41, 56)} 290.0
# {'time': datetime.datetime(2022, 8, 1, 11, 56, 56)} 290.0
# {'time': datetime.datetime(2022, 8, 1, 12, 11, 56)} 306.0
# {'time': datetime.datetime(2022, 8, 1, 12, 26, 55)} 306.0
# {'time': datetime.datetime(2022, 8, 1, 12, 41, 55)} 294.0
# {'time': datetime.datetime(2022, 8, 1, 12, 56, 56)} 294.0
# {'time': datetime.datetime(2022, 8, 1, 13, 11, 55)} 265.0
# {'time': datetime.datetime(2022, 8, 1, 13, 26, 55)} 265.0
# {'time': datetime.datetime(2022, 8, 1, 13, 41, 56)} 217.0
# {'time': datetime.datetime(2022, 8, 1, 13, 56, 56)} 217.0
# {'time': datetime.datetime(2022, 8, 1, 14, 11, 55)} 188.0
# {'time': datetime.datetime(2022, 8, 1, 14, 26, 55)} 188.0
# {'time': datetime.datetime(2022, 8, 1, 14, 41, 55)} 236.0
# {'time': datetime.datetime(2022, 8, 1, 14, 56, 56)} 236.0
# {'time': datetime.datetime(2022, 8, 1, 15, 11, 56)} 219.0
# {'time': datetime.datetime(2022, 8, 1, 15, 26, 55)} 219.0
# {'time': datetime.datetime(2022, 8, 1, 15, 41, 55)} 144.0
# {'time': datetime.datetime(2022, 8, 1, 15, 56, 56)} 144.0
# {'time': datetime.datetime(2022, 8, 1, 16, 11, 55)} 102.0
# {'time': datetime.datetime(2022, 8, 1, 16, 26, 56)} 102.0
# {'time': datetime.datetime(2022, 8, 1, 16, 41, 56)} 84.0
# {'time': datetime.datetime(2022, 8, 1, 16, 56, 56)} 84.0
# {'time': datetime.datetime(2022, 8, 1, 17, 11, 55)} 124.0
# {'time': datetime.datetime(2022, 8, 1, 17, 26, 56)} 124.0
# {'time': datetime.datetime(2022, 8, 1, 17, 41, 55)} 105.0
# {'time': datetime.datetime(2022, 8, 1, 17, 56, 56)} 105.0
# {'time': datetime.datetime(2022, 8, 1, 18, 11, 56)} 105.0
# {'time': datetime.datetime(2022, 8, 1, 18, 26, 56)} 105.0
# {'time': datetime.datetime(2022, 8, 1, 18, 41, 56)} 111.0
# {'time': datetime.datetime(2022, 8, 1, 18, 56, 56)} 111.0
# {'time': datetime.datetime(2022, 8, 1, 19, 11, 55)} 96.0
# {'time': datetime.datetime(2022, 8, 1, 19, 26, 56)} 96.0
# {'time': datetime.datetime(2022, 8, 1, 19, 41, 56)} 72.0
# {'time': datetime.datetime(2022, 8, 1, 19, 56, 55)} 72.0
# {'time': datetime.datetime(2022, 8, 1, 20, 11, 56)} 53.0
# {'time': datetime.datetime(2022, 8, 1, 20, 26, 55)} 53.0
# {'time': datetime.datetime(2022, 8, 1, 20, 41, 56)} 50.0
# {'time': datetime.datetime(2022, 8, 1, 20, 56, 56)} 50.0
# {'time': datetime.datetime(2022, 8, 1, 21, 11, 56)} 70.0
# {'time': datetime.datetime(2022, 8, 1, 21, 26, 55)} 70.0
# {'time': datetime.datetime(2022, 8, 1, 21, 41, 56)} 71.0
# {'time': datetime.datetime(2022, 8, 1, 21, 56, 56)} 71.0
# {'time': datetime.datetime(2022, 8, 1, 22, 11, 56)} 76.0
# {'time': datetime.datetime(2022, 8, 1, 22, 26, 55)} 76.0
# {'time': datetime.datetime(2022, 8, 1, 22, 41, 55)} 59.0
# {'time': datetime.datetime(2022, 8, 1, 22, 56, 55)} 59.0
# {'time': datetime.datetime(2022, 8, 1, 23, 11, 55)} 96.0
# {'time': datetime.datetime(2022, 8, 1, 23, 26, 56)} 96.0
# {'time': datetime.datetime(2022, 8, 1, 23, 41, 55)} 138.0
# {'time': datetime.datetime(2022, 8, 1, 23, 56, 55)} 138.0
# {'time': datetime.datetime(2022, 8, 2, 0, 11, 56)} 114.0
# {'time': datetime.datetime(2022, 8, 2, 0, 26, 56)} 145.0
# {'time': datetime.datetime(2022, 8, 2, 0, 41, 55)} 145.0
# {'time': datetime.datetime(2022, 8, 2, 0, 56, 57)} 145.0
# {'time': datetime.datetime(2022, 8, 2, 1, 11, 55)} 189.0
# {'time': datetime.datetime(2022, 8, 2, 1, 26, 55)} 189.0
# {'time': datetime.datetime(2022, 8, 2, 1, 41, 56)} 161.0
# {'time': datetime.datetime(2022, 8, 2, 1, 56, 55)} 161.0
# {'time': datetime.datetime(2022, 8, 2, 2, 11, 55)} 134.0
# {'time': datetime.datetime(2022, 8, 2, 2, 26, 55)} 134.0
# {'time': datetime.datetime(2022, 8, 2, 2, 41, 56)} 150.0
# {'time': datetime.datetime(2022, 8, 2, 2, 56, 55)} 150.0
# {'time': datetime.datetime(2022, 8, 2, 3, 11, 56)} 157.0
# {'time': datetime.datetime(2022, 8, 2, 3, 26, 55)} 157.0
# {'time': datetime.datetime(2022, 8, 2, 3, 41, 55)} 187.0
# {'time': datetime.datetime(2022, 8, 2, 3, 56, 55)} 187.0
# {'time': datetime.datetime(2022, 8, 2, 4, 11, 56)} 225.0
# {'time': datetime.datetime(2022, 8, 2, 4, 26, 56)} 225.0
# {'time': datetime.datetime(2022, 8, 2, 4, 41, 56)} 326.0
# {'time': datetime.datetime(2022, 8, 2, 4, 56, 55)} 326.0
# {'time': datetime.datetime(2022, 8, 2, 5, 11, 56)} 170.0
# {'time': datetime.datetime(2022, 8, 2, 5, 26, 55)} 170.0
# {'time': datetime.datetime(2022, 8, 2, 5, 41, 55)} 290.0
# {'time': datetime.datetime(2022, 8, 2, 5, 56, 56)} 290.0
# {'time': datetime.datetime(2022, 8, 2, 6, 11, 56)} 335.0
# {'time': datetime.datetime(2022, 8, 2, 6, 26, 56)} 335.0
# {'time': datetime.datetime(2022, 8, 2, 6, 41, 56)} 342.0
# {'time': datetime.datetime(2022, 8, 2, 6, 56, 56)} 342.0
# {'time': datetime.datetime(2022, 8, 2, 7, 11, 55)} 331.0
# {'time': datetime.datetime(2022, 8, 2, 7, 26, 56)} 331.0
# {'time': datetime.datetime(2022, 8, 2, 7, 41, 55)} 403.0
# {'time': datetime.datetime(2022, 8, 2, 7, 56, 55)} 403.0
# {'time': datetime.datetime(2022, 8, 2, 8, 11, 55)} 374.0
# {'time': datetime.datetime(2022, 8, 2, 8, 26, 56)} 374.0
# {'time': datetime.datetime(2022, 8, 2, 8, 41, 56)} 303.0
# {'time': datetime.datetime(2022, 8, 2, 8, 56, 56)} 303.0
# {'time': datetime.datetime(2022, 8, 2, 9, 11, 56)} 243.0
# {'time': datetime.datetime(2022, 8, 2, 9, 26, 55)} 243.0
# {'time': datetime.datetime(2022, 8, 2, 9, 41, 55)} 457.0
# {'time': datetime.datetime(2022, 8, 2, 9, 56, 55)} 457.0
# {'time': datetime.datetime(2022, 8, 2, 10, 11, 56)} 439.0
# {'time': datetime.datetime(2022, 8, 2, 10, 26, 55)} 439.0
# {'time': datetime.datetime(2022, 8, 2, 10, 41, 56)} 254.0
# {'time': datetime.datetime(2022, 8, 2, 10, 56, 55)} 254.0
# {'time': datetime.datetime(2022, 8, 2, 11, 11, 55)} 248.0
# {'time': datetime.datetime(2022, 8, 2, 11, 26, 55)} 248.0
# {'time': datetime.datetime(2022, 8, 2, 11, 41, 55)} 238.0
# {'time': datetime.datetime(2022, 8, 2, 11, 56, 55)} 238.0
# {'time': datetime.datetime(2022, 8, 2, 12, 11, 56)} 233.0
# {'time': datetime.datetime(2022, 8, 2, 12, 26, 56)} 233.0
# {'time': datetime.datetime(2022, 8, 2, 12, 41, 56)} 189.0
# {'time': datetime.datetime(2022, 8, 2, 12, 56, 55)} 189.0
# {'time': datetime.datetime(2022, 8, 2, 13, 11, 56)} 281.0
# {'time': datetime.datetime(2022, 8, 2, 13, 26, 56)} 281.0
# {'time': datetime.datetime(2022, 8, 2, 13, 41, 55)} 233.0
# {'time': datetime.datetime(2022, 8, 2, 13, 56, 56)} 233.0
# {'time': datetime.datetime(2022, 8, 2, 14, 11, 55)} 234.0
# {'time': datetime.datetime(2022, 8, 2, 14, 26, 55)} 234.0
# {'time': datetime.datetime(2022, 8, 2, 14, 41, 55)} 202.0
# {'time': datetime.datetime(2022, 8, 2, 14, 56, 55)} 202.0
# {'time': datetime.datetime(2022, 8, 2, 15, 11, 56)} 162.0
# {'time': datetime.datetime(2022, 8, 2, 15, 26, 56)} 162.0
# {'time': datetime.datetime(2022, 8, 2, 15, 41, 56)} 155.0
# {'time': datetime.datetime(2022, 8, 2, 15, 56, 55)} 155.0
# {'time': datetime.datetime(2022, 8, 2, 16, 11, 56)} 203.0
# {'time': datetime.datetime(2022, 8, 2, 16, 26, 56)} 203.0
# {'time': datetime.datetime(2022, 8, 2, 16, 41, 56)} 92.0
# {'time': datetime.datetime(2022, 8, 2, 16, 56, 56)} 92.0
# {'time': datetime.datetime(2022, 8, 2, 17, 11, 56)} 69.0
# {'time': datetime.datetime(2022, 8, 2, 17, 26, 56)} 69.0
# {'time': datetime.datetime(2022, 8, 2, 17, 41, 56)} 60.0
# {'time': datetime.datetime(2022, 8, 2, 17, 56, 56)} 60.0
# {'time': datetime.datetime(2022, 8, 2, 18, 11, 56)} 86.0
# {'time': datetime.datetime(2022, 8, 2, 18, 26, 55)} 86.0
# {'time': datetime.datetime(2022, 8, 2, 18, 41, 55)} 75.0
# {'time': datetime.datetime(2022, 8, 2, 18, 56, 55)} 75.0
# {'time': datetime.datetime(2022, 8, 2, 19, 11, 55)} 70.0
# {'time': datetime.datetime(2022, 8, 2, 19, 26, 56)} 70.0
# {'time': datetime.datetime(2022, 8, 2, 19, 41, 56)} 62.0
# {'time': datetime.datetime(2022, 8, 2, 19, 56, 55)} 62.0
# {'time': datetime.datetime(2022, 8, 2, 20, 11, 55)} 40.0
# {'time': datetime.datetime(2022, 8, 2, 20, 26, 55)} 40.0
# {'time': datetime.datetime(2022, 8, 2, 20, 41, 56)} 34.0
# {'time': datetime.datetime(2022, 8, 2, 20, 56, 56)} 34.0
# {'time': datetime.datetime(2022, 8, 2, 21, 11, 55)} 38.0
# {'time': datetime.datetime(2022, 8, 2, 21, 26, 56)} 38.0
# {'time': datetime.datetime(2022, 8, 2, 21, 41, 56)} 42.0
# {'time': datetime.datetime(2022, 8, 2, 21, 56, 56)} 36.0
# {'time': datetime.datetime(2022, 8, 2, 22, 11, 56)} 36.0
# {'time': datetime.datetime(2022, 8, 2, 22, 26, 55)} 36.0
# {'time': datetime.datetime(2022, 8, 2, 22, 41, 56)} 55.0
# {'time': datetime.datetime(2022, 8, 2, 22, 56, 55)} 55.0
# {'time': datetime.datetime(2022, 8, 2, 23, 11, 56)} 56.0
# {'time': datetime.datetime(2022, 8, 2, 23, 26, 56)} 56.0
# {'time': datetime.datetime(2022, 8, 2, 23, 41, 55)} 83.0
# {'time': datetime.datetime(2022, 8, 2, 23, 56, 55)} 83.0
# {'time': datetime.datetime(2022, 8, 3, 0, 11, 56)} 102.0
# {'time': datetime.datetime(2022, 8, 3, 0, 26, 55)} 102.0
# {'time': datetime.datetime(2022, 8, 3, 0, 41, 55)} 98.0
# {'time': datetime.datetime(2022, 8, 3, 0, 56, 55)} 98.0
# {'time': datetime.datetime(2022, 8, 3, 1, 11, 56)} 78.0
# {'time': datetime.datetime(2022, 8, 3, 1, 26, 56)} 78.0
# {'time': datetime.datetime(2022, 8, 3, 1, 41, 56)} 68.0
# {'time': datetime.datetime(2022, 8, 3, 1, 56, 55)} 68.0
# {'time': datetime.datetime(2022, 8, 3, 2, 11, 55)} 66.0
# {'time': datetime.datetime(2022, 8, 3, 2, 26, 55)} 66.0
# {'time': datetime.datetime(2022, 8, 3, 2, 41, 55)} 64.0
# {'time': datetime.datetime(2022, 8, 3, 2, 56, 56)} 64.0
# {'time': datetime.datetime(2022, 8, 3, 3, 11, 56)} 76.0
# {'time': datetime.datetime(2022, 8, 3, 3, 26, 55)} 76.0
# {'time': datetime.datetime(2022, 8, 3, 3, 41, 55)} 78.0
# {'time': datetime.datetime(2022, 8, 3, 3, 56, 56)} 78.0
# {'time': datetime.datetime(2022, 8, 3, 4, 11, 55)} 67.0
# {'time': datetime.datetime(2022, 8, 3, 4, 26, 55)} 67.0
# {'time': datetime.datetime(2022, 8, 3, 4, 41, 56)} 56.0
# {'time': datetime.datetime(2022, 8, 3, 4, 56, 56)} 56.0
# {'time': datetime.datetime(2022, 8, 3, 5, 11, 56)} 54.0
# {'time': datetime.datetime(2022, 8, 3, 5, 26, 56)} 54.0
# {'time': datetime.datetime(2022, 8, 3, 5, 41, 55)} 42.0
# {'time': datetime.datetime(2022, 8, 3, 5, 56, 55)} 42.0
# {'time': datetime.datetime(2022, 8, 3, 6, 11, 56)} 60.0
# {'time': datetime.datetime(2022, 8, 3, 6, 26, 55)} 60.0
# {'time': datetime.datetime(2022, 8, 3, 6, 41, 55)} 66.0
# {'time': datetime.datetime(2022, 8, 3, 6, 56, 55)} 66.0
# {'time': datetime.datetime(2022, 8, 3, 7, 11, 55)} 66.0
# {'time': datetime.datetime(2022, 8, 3, 7, 26, 55)} 66.0
# {'time': datetime.datetime(2022, 8, 3, 7, 41, 56)} 70.0
# {'time': datetime.datetime(2022, 8, 3, 7, 56, 56)} 70.0
# {'time': datetime.datetime(2022, 8, 3, 8, 11, 55)} 82.0
# {'time': datetime.datetime(2022, 8, 3, 8, 26, 55)} 82.0
# {'time': datetime.datetime(2022, 8, 3, 8, 41, 56)} 74.0
# {'time': datetime.datetime(2022, 8, 3, 8, 56, 55)} 74.0
# {'time': datetime.datetime(2022, 8, 3, 9, 11, 55)} 88.0
# {'time': datetime.datetime(2022, 8, 3, 9, 26, 56)} 88.0
# {'time': datetime.datetime(2022, 8, 3, 9, 41, 56)} 182.0
# {'time': datetime.datetime(2022, 8, 3, 9, 56, 55)} 182.0
# {'time': datetime.datetime(2022, 8, 3, 10, 11, 55)} 182.0
# {'time': datetime.datetime(2022, 8, 3, 10, 26, 55)} 182.0
# {'time': datetime.datetime(2022, 8, 3, 10, 41, 55)} 226.0
# {'time': datetime.datetime(2022, 8, 3, 10, 56, 57)} 226.0
# {'time': datetime.datetime(2022, 8, 3, 11, 11, 55)} 176.0
# {'time': datetime.datetime(2022, 8, 3, 11, 26, 56)} 176.0
# {'time': datetime.datetime(2022, 8, 3, 11, 41, 56)} 189.0
# {'time': datetime.datetime(2022, 8, 3, 11, 56, 56)} 189.0
# {'time': datetime.datetime(2022, 8, 3, 12, 11, 56)} 266.0
# {'time': datetime.datetime(2022, 8, 3, 12, 26, 55)} 149.0
# {'time': datetime.datetime(2022, 8, 3, 12, 41, 55)} 149.0
# {'time': datetime.datetime(2022, 8, 3, 12, 56, 56)} 149.0
# {'time': datetime.datetime(2022, 8, 3, 13, 11, 56)} 215.0
# {'time': datetime.datetime(2022, 8, 3, 13, 26, 55)} 215.0
# {'time': datetime.datetime(2022, 8, 3, 13, 41, 56)} 172.0
# {'time': datetime.datetime(2022, 8, 3, 13, 56, 56)} 172.0
# {'time': datetime.datetime(2022, 8, 3, 14, 11, 56)} 157.0
# {'time': datetime.datetime(2022, 8, 3, 14, 26, 55)} 157.0
# {'time': datetime.datetime(2022, 8, 3, 14, 41, 55)} 209.0
# {'time': datetime.datetime(2022, 8, 3, 14, 56, 56)} 209.0
# {'time': datetime.datetime(2022, 8, 3, 15, 11, 56)} 203.0
# {'time': datetime.datetime(2022, 8, 3, 15, 26, 56)} 203.0
# {'time': datetime.datetime(2022, 8, 3, 15, 41, 56)} 145.0
# {'time': datetime.datetime(2022, 8, 3, 15, 56, 55)} 145.0
# {'time': datetime.datetime(2022, 8, 3, 16, 11, 55)} 182.0
# {'time': datetime.datetime(2022, 8, 3, 16, 26, 56)} 182.0
# {'time': datetime.datetime(2022, 8, 3, 16, 41, 55)} 400.0
# {'time': datetime.datetime(2022, 8, 3, 16, 56, 55)} 400.0
# {'time': datetime.datetime(2022, 8, 3, 17, 11, 56)} 73.0
# {'time': datetime.datetime(2022, 8, 3, 17, 26, 56)} 73.0
# {'time': datetime.datetime(2022, 8, 3, 17, 41, 55)} 50.0
# {'time': datetime.datetime(2022, 8, 3, 17, 56, 56)} 50.0
# {'time': datetime.datetime(2022, 8, 3, 18, 11, 55)} 53.0
# {'time': datetime.datetime(2022, 8, 3, 18, 26, 56)} 53.0
# {'time': datetime.datetime(2022, 8, 3, 18, 41, 56)} 39.0
# {'time': datetime.datetime(2022, 8, 3, 18, 56, 55)} 39.0
# {'time': datetime.datetime(2022, 8, 3, 19, 11, 56)} 53.0
# {'time': datetime.datetime(2022, 8, 3, 19, 26, 56)} 53.0
# {'time': datetime.datetime(2022, 8, 3, 19, 41, 56)} 53.0
# {'time': datetime.datetime(2022, 8, 3, 19, 56, 55)} 53.0
# {'time': datetime.datetime(2022, 8, 3, 20, 11, 56)} 45.0
# {'time': datetime.datetime(2022, 8, 3, 20, 26, 56)} 45.0
# {'time': datetime.datetime(2022, 8, 3, 20, 41, 56)} 35.0
# {'time': datetime.datetime(2022, 8, 3, 20, 56, 56)} 35.0
# {'time': datetime.datetime(2022, 8, 3, 21, 11, 55)} 34.0
# {'time': datetime.datetime(2022, 8, 3, 21, 26, 55)} 34.0
# {'time': datetime.datetime(2022, 8, 3, 21, 41, 56)} 37.0
# {'time': datetime.datetime(2022, 8, 3, 21, 56, 55)} 37.0
# {'time': datetime.datetime(2022, 8, 3, 22, 11, 55)} 36.0
# {'time': datetime.datetime(2022, 8, 3, 22, 26, 55)} 36.0
# {'time': datetime.datetime(2022, 8, 3, 22, 41, 55)} 31.0
# {'time': datetime.datetime(2022, 8, 3, 22, 56, 55)} 31.0
# {'time': datetime.datetime(2022, 8, 3, 23, 11, 55)} 36.0
# {'time': datetime.datetime(2022, 8, 3, 23, 26, 55)} 36.0
# {'time': datetime.datetime(2022, 8, 3, 23, 41, 56)} 35.0
# {'time': datetime.datetime(2022, 8, 3, 23, 56, 56)} 35.0
# {'time': datetime.datetime(2022, 8, 4, 0, 11, 55)} 40.0
# {'time': datetime.datetime(2022, 8, 4, 0, 26, 55)} 40.0
# {'time': datetime.datetime(2022, 8, 4, 0, 41, 56)} 33.0
# {'time': datetime.datetime(2022, 8, 4, 0, 56, 55)} 33.0
# {'time': datetime.datetime(2022, 8, 4, 1, 11, 56)} 28.0
# {'time': datetime.datetime(2022, 8, 4, 1, 26, 56)} 28.0
# {'time': datetime.datetime(2022, 8, 4, 1, 41, 55)} 28.0
# {'time': datetime.datetime(2022, 8, 4, 1, 56, 55)} 28.0
# {'time': datetime.datetime(2022, 8, 4, 2, 11, 55)} 37.0
# {'time': datetime.datetime(2022, 8, 4, 2, 26, 55)} 37.0
# {'time': datetime.datetime(2022, 8, 4, 2, 41, 55)} 41.0
# {'time': datetime.datetime(2022, 8, 4, 2, 56, 55)} 41.0
# {'time': datetime.datetime(2022, 8, 4, 3, 11, 55)} 42.0
# {'time': datetime.datetime(2022, 8, 4, 3, 26, 55)} 42.0
# {'time': datetime.datetime(2022, 8, 4, 3, 41, 56)} 48.0
# {'time': datetime.datetime(2022, 8, 4, 3, 56, 55)} 48.0
# {'time': datetime.datetime(2022, 8, 4, 4, 11, 56)} 36.0
# {'time': datetime.datetime(2022, 8, 4, 4, 26, 55)} 36.0
# {'time': datetime.datetime(2022, 8, 4, 4, 41, 55)} 31.0
# {'time': datetime.datetime(2022, 8, 4, 4, 56, 55)} 31.0
# {'time': datetime.datetime(2022, 8, 4, 5, 11, 55)} 27.0
# {'time': datetime.datetime(2022, 8, 4, 5, 26, 56)} 27.0
# {'time': datetime.datetime(2022, 8, 4, 5, 41, 55)} 32.0
# {'time': datetime.datetime(2022, 8, 4, 5, 56, 56)} 32.0
# {'time': datetime.datetime(2022, 8, 4, 6, 11, 55)} 36.0
# {'time': datetime.datetime(2022, 8, 4, 6, 26, 56)} 36.0
# {'time': datetime.datetime(2022, 8, 4, 6, 41, 55)} 42.0
# {'time': datetime.datetime(2022, 8, 4, 6, 56, 55)} 42.0
# {'time': datetime.datetime(2022, 8, 4, 7, 11, 56)} 42.0
# {'time': datetime.datetime(2022, 8, 4, 7, 26, 56)} 42.0
# {'time': datetime.datetime(2022, 8, 4, 7, 41, 55)} 46.0
# {'time': datetime.datetime(2022, 8, 4, 7, 56, 55)} 46.0
# {'time': datetime.datetime(2022, 8, 4, 8, 11, 55)} 48.0
# {'time': datetime.datetime(2022, 8, 4, 8, 26, 55)} 48.0
# {'time': datetime.datetime(2022, 8, 4, 8, 41, 56)} 45.0
# {'time': datetime.datetime(2022, 8, 4, 8, 56, 56)} 45.0
# {'time': datetime.datetime(2022, 8, 4, 9, 11, 56)} 39.0
# {'time': datetime.datetime(2022, 8, 4, 9, 26, 56)} 39.0
# {'time': datetime.datetime(2022, 8, 4, 9, 41, 55)} 82.0
# {'time': datetime.datetime(2022, 8, 4, 9, 56, 55)} 82.0
# {'time': datetime.datetime(2022, 8, 4, 10, 11, 56)} 76.0
# {'time': datetime.datetime(2022, 8, 4, 10, 26, 56)} 76.0
# {'time': datetime.datetime(2022, 8, 4, 10, 41, 55)} 86.0
# {'time': datetime.datetime(2022, 8, 4, 10, 56, 55)} 86.0
# {'time': datetime.datetime(2022, 8, 4, 11, 11, 56)} 173.0
# {'time': datetime.datetime(2022, 8, 4, 11, 26, 55)} 173.0
# {'time': datetime.datetime(2022, 8, 4, 11, 41, 55)} 239.0
# {'time': datetime.datetime(2022, 8, 4, 11, 56, 55)} 247.0
# {'time': datetime.datetime(2022, 8, 4, 12, 11, 55)} 247.0
# {'time': datetime.datetime(2022, 8, 4, 12, 26, 55)} 247.0
# {'time': datetime.datetime(2022, 8, 4, 12, 41, 56)} 222.0
# {'time': datetime.datetime(2022, 8, 4, 12, 56, 55)} 222.0
# {'time': datetime.datetime(2022, 8, 4, 13, 11, 55)} 251.0
# {'time': datetime.datetime(2022, 8, 4, 13, 26, 56)} 251.0
# {'time': datetime.datetime(2022, 8, 4, 13, 41, 56)} 206.0
# {'time': datetime.datetime(2022, 8, 4, 13, 56, 56)} 206.0
# {'time': datetime.datetime(2022, 8, 4, 14, 11, 55)} 199.0
# {'time': datetime.datetime(2022, 8, 4, 14, 26, 56)} 199.0
# {'time': datetime.datetime(2022, 8, 4, 14, 41, 55)} 192.0
# {'time': datetime.datetime(2022, 8, 4, 14, 56, 55)} 192.0
# {'time': datetime.datetime(2022, 8, 4, 15, 11, 56)} 183.0
# {'time': datetime.datetime(2022, 8, 4, 15, 26, 56)} 183.0
# {'time': datetime.datetime(2022, 8, 4, 15, 41, 56)} 172.0
# {'time': datetime.datetime(2022, 8, 4, 15, 56, 56)} 172.0
# {'time': datetime.datetime(2022, 8, 4, 16, 11, 56)} 150.0
# {'time': datetime.datetime(2022, 8, 4, 16, 26, 55)} 150.0
# {'time': datetime.datetime(2022, 8, 4, 16, 41, 56)} 140.0
# {'time': datetime.datetime(2022, 8, 4, 16, 56, 56)} 140.0
# {'time': datetime.datetime(2022, 8, 4, 17, 11, 56)} 165.0
# {'time': datetime.datetime(2022, 8, 4, 17, 26, 56)} 165.0
# {'time': datetime.datetime(2022, 8, 4, 17, 41, 56)} 163.0
# {'time': datetime.datetime(2022, 8, 4, 17, 56, 57)} 163.0
# {'time': datetime.datetime(2022, 8, 4, 18, 11, 55)} 144.0
# {'time': datetime.datetime(2022, 8, 4, 18, 26, 56)} 144.0
# {'time': datetime.datetime(2022, 8, 4, 18, 41, 55)} 115.0
# {'time': datetime.datetime(2022, 8, 4, 18, 56, 55)} 115.0
# {'time': datetime.datetime(2022, 8, 4, 19, 11, 56)} 109.0
# {'time': datetime.datetime(2022, 8, 4, 19, 26, 56)} 109.0
# {'time': datetime.datetime(2022, 8, 4, 19, 41, 56)} 100.0
# {'time': datetime.datetime(2022, 8, 4, 19, 56, 56)} 71.0
# {'time': datetime.datetime(2022, 8, 4, 20, 11, 55)} 71.0
# {'time': datetime.datetime(2022, 8, 4, 20, 26, 55)} 71.0
# {'time': datetime.datetime(2022, 8, 4, 20, 41, 56)} 56.0
# {'time': datetime.datetime(2022, 8, 4, 20, 56, 55)} 56.0
# {'time': datetime.datetime(2022, 8, 4, 21, 11, 55)} 58.0
# {'time': datetime.datetime(2022, 8, 4, 21, 26, 55)} 58.0
# {'time': datetime.datetime(2022, 8, 4, 21, 41, 55)} 55.0
# {'time': datetime.datetime(2022, 8, 4, 21, 56, 55)} 55.0
# {'time': datetime.datetime(2022, 8, 4, 22, 11, 56)} 48.0
# {'time': datetime.datetime(2022, 8, 4, 22, 26, 55)} 48.0
# {'time': datetime.datetime(2022, 8, 4, 22, 41, 56)} 48.0
# {'time': datetime.datetime(2022, 8, 4, 22, 56, 56)} 48.0
# {'time': datetime.datetime(2022, 8, 4, 23, 11, 56)} 45.0
# {'time': datetime.datetime(2022, 8, 4, 23, 26, 56)} 45.0
# {'time': datetime.datetime(2022, 8, 4, 23, 41, 55)} 46.0
# {'time': datetime.datetime(2022, 8, 4, 23, 56, 56)} 46.0
# {'time': datetime.datetime(2022, 8, 5, 0, 11, 55)} 43.0
# {'time': datetime.datetime(2022, 8, 5, 0, 26, 55)} 43.0
# {'time': datetime.datetime(2022, 8, 5, 0, 41, 55)} 48.0
# {'time': datetime.datetime(2022, 8, 5, 0, 56, 56)} 48.0
# {'time': datetime.datetime(2022, 8, 5, 1, 11, 55)} 40.0
# {'time': datetime.datetime(2022, 8, 5, 1, 26, 55)} 40.0
# {'time': datetime.datetime(2022, 8, 5, 1, 41, 56)} 37.0
# {'time': datetime.datetime(2022, 8, 5, 1, 56, 56)} 37.0
# {'time': datetime.datetime(2022, 8, 5, 2, 11, 55)} 50.0
# {'time': datetime.datetime(2022, 8, 5, 2, 26, 56)} 50.0
# {'time': datetime.datetime(2022, 8, 5, 2, 41, 56)} 31.0
# {'time': datetime.datetime(2022, 8, 5, 2, 56, 56)} 31.0
# {'time': datetime.datetime(2022, 8, 5, 3, 11, 55)} 30.0
# {'time': datetime.datetime(2022, 8, 5, 3, 26, 56)} 30.0
# {'time': datetime.datetime(2022, 8, 5, 3, 41, 55)} 34.0
# {'time': datetime.datetime(2022, 8, 5, 3, 56, 55)} 34.0
# {'time': datetime.datetime(2022, 8, 5, 4, 11, 56)} 37.0
# {'time': datetime.datetime(2022, 8, 5, 4, 26, 55)} 37.0
# {'time': datetime.datetime(2022, 8, 5, 4, 41, 56)} 37.0
# {'time': datetime.datetime(2022, 8, 5, 4, 56, 55)} 37.0
# {'time': datetime.datetime(2022, 8, 5, 5, 11, 56)} 34.0
# {'time': datetime.datetime(2022, 8, 5, 5, 26, 56)} 34.0
# {'time': datetime.datetime(2022, 8, 5, 5, 41, 56)} 33.0
# {'time': datetime.datetime(2022, 8, 5, 5, 56, 56)} 46.0
# {'time': datetime.datetime(2022, 8, 5, 6, 11, 55)} 46.0
# {'time': datetime.datetime(2022, 8, 5, 6, 26, 55)} 46.0
# {'time': datetime.datetime(2022, 8, 5, 6, 41, 55)} 88.0
# {'time': datetime.datetime(2022, 8, 5, 6, 56, 55)} 88.0
# {'time': datetime.datetime(2022, 8, 5, 7, 11, 56)} 143.0
# {'time': datetime.datetime(2022, 8, 5, 7, 26, 55)} 143.0
# {'time': datetime.datetime(2022, 8, 5, 7, 41, 55)} 173.0
# {'time': datetime.datetime(2022, 8, 5, 7, 56, 56)} 173.0
# {'time': datetime.datetime(2022, 8, 5, 8, 11, 56)} 280.0
# {'time': datetime.datetime(2022, 8, 5, 8, 26, 55)} 280.0
# {'time': datetime.datetime(2022, 8, 5, 8, 41, 56)} 299.0
# {'time': datetime.datetime(2022, 8, 5, 8, 56, 56)} 299.0
# {'time': datetime.datetime(2022, 8, 5, 9, 11, 56)} 303.0
# {'time': datetime.datetime(2022, 8, 5, 9, 26, 56)} 303.0
# {'time': datetime.datetime(2022, 8, 5, 9, 41, 55)} 266.0
# {'time': datetime.datetime(2022, 8, 5, 9, 56, 55)} 266.0
# {'time': datetime.datetime(2022, 8, 5, 10, 11, 56)} 286.0
# {'time': datetime.datetime(2022, 8, 5, 10, 26, 55)} 286.0
# {'time': datetime.datetime(2022, 8, 5, 10, 41, 56)} 314.0
# {'time': datetime.datetime(2022, 8, 5, 10, 56, 55)} 314.0
# {'time': datetime.datetime(2022, 8, 5, 11, 11, 56)} 206.0
# {'time': datetime.datetime(2022, 8, 5, 11, 26, 55)} 206.0
# {'time': datetime.datetime(2022, 8, 5, 11, 41, 56)} 207.0
# {'time': datetime.datetime(2022, 8, 5, 11, 56, 55)} 207.0
# {'time': datetime.datetime(2022, 8, 5, 12, 11, 55)} 204.0
# {'time': datetime.datetime(2022, 8, 5, 12, 26, 56)} 204.0
# {'time': datetime.datetime(2022, 8, 5, 12, 41, 56)} 174.0
# {'time': datetime.datetime(2022, 8, 5, 12, 56, 56)} 174.0
# {'time': datetime.datetime(2022, 8, 5, 13, 11, 56)} 160.0
# {'time': datetime.datetime(2022, 8, 5, 13, 26, 55)} 160.0
# {'time': datetime.datetime(2022, 8, 5, 13, 41, 56)} 190.0
# {'time': datetime.datetime(2022, 8, 5, 13, 56, 56)} 190.0
# {'time': datetime.datetime(2022, 8, 5, 14, 11, 56)} 182.0
# {'time': datetime.datetime(2022, 8, 5, 14, 26, 56)} 182.0
# {'time': datetime.datetime(2022, 8, 5, 14, 41, 56)} 95.0
# {'time': datetime.datetime(2022, 8, 5, 14, 56, 56)} 95.0
# {'time': datetime.datetime(2022, 8, 5, 15, 11, 56)} 166.0
# {'time': datetime.datetime(2022, 8, 5, 15, 26, 56)} 166.0
# {'time': datetime.datetime(2022, 8, 5, 15, 41, 56)} 150.0
# {'time': datetime.datetime(2022, 8, 5, 15, 56, 55)} 150.0
# {'time': datetime.datetime(2022, 8, 5, 16, 11, 56)} 180.0
# {'time': datetime.datetime(2022, 8, 5, 16, 26, 55)} 89.0
# {'time': datetime.datetime(2022, 8, 5, 16, 41, 56)} 89.0
# {'time': datetime.datetime(2022, 8, 5, 16, 56, 55)} 89.0
# {'time': datetime.datetime(2022, 8, 5, 17, 11, 56)} 55.0
# {'time': datetime.datetime(2022, 8, 5, 17, 26, 56)} 55.0
# {'time': datetime.datetime(2022, 8, 5, 17, 41, 55)} 45.0
# {'time': datetime.datetime(2022, 8, 5, 17, 56, 56)} 45.0
# {'time': datetime.datetime(2022, 8, 5, 18, 11, 55)} 44.0
# {'time': datetime.datetime(2022, 8, 5, 18, 26, 56)} 44.0
# {'time': datetime.datetime(2022, 8, 5, 18, 41, 55)} 43.0
# {'time': datetime.datetime(2022, 8, 5, 18, 56, 55)} 43.0
# {'time': datetime.datetime(2022, 8, 5, 19, 11, 55)} 51.0
# {'time': datetime.datetime(2022, 8, 5, 19, 26, 56)} 47.0
# {'time': datetime.datetime(2022, 8, 5, 19, 41, 55)} 47.0
# {'time': datetime.datetime(2022, 8, 5, 19, 56, 56)} 47.0
# {'time': datetime.datetime(2022, 8, 5, 20, 11, 55)} 36.0
# {'time': datetime.datetime(2022, 8, 5, 20, 26, 56)} 36.0
# {'time': datetime.datetime(2022, 8, 5, 20, 41, 56)} 73.0
# {'time': datetime.datetime(2022, 8, 5, 20, 56, 56)} 73.0
# {'time': datetime.datetime(2022, 8, 5, 21, 11, 55)} 85.0
# {'time': datetime.datetime(2022, 8, 5, 21, 26, 56)} 85.0
# {'time': datetime.datetime(2022, 8, 5, 21, 41, 55)} 96.0
# {'time': datetime.datetime(2022, 8, 5, 21, 56, 56)} 96.0
# {'time': datetime.datetime(2022, 8, 5, 22, 11, 56)} 93.0
# {'time': datetime.datetime(2022, 8, 5, 22, 26, 55)} 93.0
# {'time': datetime.datetime(2022, 8, 5, 22, 41, 55)} 110.0
# {'time': datetime.datetime(2022, 8, 5, 22, 56, 55)} 110.0
# {'time': datetime.datetime(2022, 8, 5, 23, 11, 56)} 127.0
# {'time': datetime.datetime(2022, 8, 5, 23, 26, 55)} 132.0
# {'time': datetime.datetime(2022, 8, 5, 23, 41, 56)} 132.0
# {'time': datetime.datetime(2022, 8, 5, 23, 56, 55)} 132.0
# {'time': datetime.datetime(2022, 8, 6, 0, 11, 56)} 135.0
# {'time': datetime.datetime(2022, 8, 6, 0, 26, 55)} 135.0
# {'time': datetime.datetime(2022, 8, 6, 0, 41, 56)} 130.0
# {'time': datetime.datetime(2022, 8, 6, 0, 56, 56)} 130.0
# {'time': datetime.datetime(2022, 8, 6, 1, 11, 55)} 124.0
# {'time': datetime.datetime(2022, 8, 6, 1, 26, 55)} 124.0
# {'time': datetime.datetime(2022, 8, 6, 1, 41, 56)} 107.0
# {'time': datetime.datetime(2022, 8, 6, 1, 56, 56)} 107.0
# {'time': datetime.datetime(2022, 8, 6, 2, 11, 55)} 101.0
# {'time': datetime.datetime(2022, 8, 6, 2, 26, 55)} 101.0
# {'time': datetime.datetime(2022, 8, 6, 2, 41, 56)} 91.0
# {'time': datetime.datetime(2022, 8, 6, 2, 56, 56)} 91.0
# {'time': datetime.datetime(2022, 8, 6, 3, 11, 55)} 115.0
# {'time': datetime.datetime(2022, 8, 6, 3, 26, 56)} 115.0
# {'time': datetime.datetime(2022, 8, 6, 3, 41, 56)} 126.0
# {'time': datetime.datetime(2022, 8, 6, 3, 56, 55)} 99.0
# {'time': datetime.datetime(2022, 8, 6, 4, 11, 55)} 99.0
# {'time': datetime.datetime(2022, 8, 6, 4, 30, 21)} 99.0
# {'time': datetime.datetime(2022, 8, 6, 4, 41, 56)} 110.0
# {'time': datetime.datetime(2022, 8, 6, 4, 56, 55)} 110.0
# {'time': datetime.datetime(2022, 8, 6, 5, 11, 55)} 135.0
# {'time': datetime.datetime(2022, 8, 6, 5, 26, 55)} 135.0
# {'time': datetime.datetime(2022, 8, 6, 5, 41, 55)} 128.0
# {'time': datetime.datetime(2022, 8, 6, 5, 56, 55)} 128.0
# {'time': datetime.datetime(2022, 8, 6, 6, 11, 56)} 143.0
# {'time': datetime.datetime(2022, 8, 6, 6, 26, 55)} 143.0
# {'time': datetime.datetime(2022, 8, 6, 6, 41, 55)} 240.0
# {'time': datetime.datetime(2022, 8, 6, 6, 56, 55)} 240.0
# {'time': datetime.datetime(2022, 8, 6, 7, 11, 55)} 292.0
# {'time': datetime.datetime(2022, 8, 6, 7, 26, 55)} 292.0
# {'time': datetime.datetime(2022, 8, 6, 7, 41, 56)} 373.0
# {'time': datetime.datetime(2022, 8, 6, 7, 56, 55)} 373.0
# {'time': datetime.datetime(2022, 8, 6, 8, 11, 56)} 404.0
# {'time': datetime.datetime(2022, 8, 6, 8, 26, 56)} 404.0
# {'time': datetime.datetime(2022, 8, 6, 8, 41, 55)} 387.0
# {'time': datetime.datetime(2022, 8, 6, 8, 56, 56)} 387.0
# {'time': datetime.datetime(2022, 8, 6, 9, 11, 56)} 290.0
# {'time': datetime.datetime(2022, 8, 6, 9, 26, 56)} 290.0
# {'time': datetime.datetime(2022, 8, 6, 9, 41, 56)} 260.0
# {'time': datetime.datetime(2022, 8, 6, 9, 56, 55)} 307.0
# {'time': datetime.datetime(2022, 8, 6, 10, 11, 55)} 307.0
# {'time': datetime.datetime(2022, 8, 6, 10, 26, 55)} 307.0
# {'time': datetime.datetime(2022, 8, 6, 10, 41, 56)} 309.0
# {'time': datetime.datetime(2022, 8, 6, 10, 56, 55)} 309.0
# {'time': datetime.datetime(2022, 8, 6, 11, 11, 56)} 318.0
# {'time': datetime.datetime(2022, 8, 6, 11, 26, 56)} 318.0
# {'time': datetime.datetime(2022, 8, 6, 11, 41, 55)} 319.0
# {'time': datetime.datetime(2022, 8, 6, 11, 56, 56)} 319.0
# {'time': datetime.datetime(2022, 8, 6, 12, 11, 56)} 402.0
# {'time': datetime.datetime(2022, 8, 6, 12, 26, 55)} 402.0
# {'time': datetime.datetime(2022, 8, 6, 12, 41, 55)} 333.0
# {'time': datetime.datetime(2022, 8, 6, 12, 56, 56)} 333.0
# {'time': datetime.datetime(2022, 8, 6, 13, 11, 56)} 311.0
# {'time': datetime.datetime(2022, 8, 6, 13, 26, 56)} 311.0
# {'time': datetime.datetime(2022, 8, 6, 13, 41, 56)} 332.0
# {'time': datetime.datetime(2022, 8, 6, 13, 56, 55)} 332.0
# {'time': datetime.datetime(2022, 8, 6, 14, 11, 56)} 289.0
# {'time': datetime.datetime(2022, 8, 6, 14, 26, 56)} 289.0
# {'time': datetime.datetime(2022, 8, 6, 14, 41, 57)} 197.0
# {'time': datetime.datetime(2022, 8, 6, 14, 56, 56)} 197.0
# {'time': datetime.datetime(2022, 8, 6, 15, 11, 56)} 175.0
# {'time': datetime.datetime(2022, 8, 6, 15, 26, 56)} 175.0
# {'time': datetime.datetime(2022, 8, 6, 15, 41, 55)} 160.0
# {'time': datetime.datetime(2022, 8, 6, 15, 56, 56)} 160.0
# {'time': datetime.datetime(2022, 8, 6, 16, 11, 56)} 162.0
# {'time': datetime.datetime(2022, 8, 6, 16, 26, 55)} 162.0
# {'time': datetime.datetime(2022, 8, 6, 16, 41, 56)} 108.0
# {'time': datetime.datetime(2022, 8, 6, 16, 56, 56)} 108.0
# {'time': datetime.datetime(2022, 8, 6, 17, 11, 56)} 106.0
# {'time': datetime.datetime(2022, 8, 6, 17, 26, 56)} 106.0
# {'time': datetime.datetime(2022, 8, 6, 17, 41, 55)} 115.0
# {'time': datetime.datetime(2022, 8, 6, 17, 56, 56)} 115.0
# {'time': datetime.datetime(2022, 8, 6, 18, 11, 56)} 90.0
# {'time': datetime.datetime(2022, 8, 6, 18, 26, 55)} 90.0
# {'time': datetime.datetime(2022, 8, 6, 18, 41, 56)} 88.0
# {'time': datetime.datetime(2022, 8, 6, 18, 56, 55)} 88.0
# {'time': datetime.datetime(2022, 8, 6, 19, 11, 55)} 98.0
# {'time': datetime.datetime(2022, 8, 6, 19, 26, 56)} 98.0
# {'time': datetime.datetime(2022, 8, 6, 19, 41, 56)} 68.0
# {'time': datetime.datetime(2022, 8, 6, 19, 56, 56)} 68.0
# {'time': datetime.datetime(2022, 8, 6, 20, 11, 55)} 26.0
# {'time': datetime.datetime(2022, 8, 6, 20, 26, 55)} 26.0
# {'time': datetime.datetime(2022, 8, 6, 20, 41, 56)} 17.0
# {'time': datetime.datetime(2022, 8, 6, 20, 56, 56)} 17.0
# {'time': datetime.datetime(2022, 8, 6, 21, 11, 55)} 17.0
# {'time': datetime.datetime(2022, 8, 6, 21, 26, 55)} 17.0
# {'time': datetime.datetime(2022, 8, 6, 21, 41, 56)} 20.0
# {'time': datetime.datetime(2022, 8, 6, 21, 56, 55)} 20.0
# {'time': datetime.datetime(2022, 8, 6, 22, 11, 56)} 21.0
# {'time': datetime.datetime(2022, 8, 6, 22, 26, 56)} 21.0
# {'time': datetime.datetime(2022, 8, 6, 22, 41, 56)} 17.0
# {'time': datetime.datetime(2022, 8, 6, 22, 56, 56)} 17.0
# {'time': datetime.datetime(2022, 8, 6, 23, 11, 55)} 16.0
# {'time': datetime.datetime(2022, 8, 6, 23, 26, 56)} 16.0
# {'time': datetime.datetime(2022, 8, 6, 23, 41, 55)} 18.0
# {'time': datetime.datetime(2022, 8, 6, 23, 56, 56)} 18.0
# {'time': datetime.datetime(2022, 8, 7, 0, 11, 55)} 19.0
# {'time': datetime.datetime(2022, 8, 7, 0, 26, 55)} 19.0
# {'time': datetime.datetime(2022, 8, 7, 0, 41, 55)} 19.0
# {'time': datetime.datetime(2022, 8, 7, 0, 56, 55)} 19.0
# {'time': datetime.datetime(2022, 8, 7, 1, 11, 55)} 16.0
# {'time': datetime.datetime(2022, 8, 7, 1, 26, 55)} 12.0
# {'time': datetime.datetime(2022, 8, 7, 1, 41, 56)} 12.0
# {'time': datetime.datetime(2022, 8, 7, 1, 56, 56)} 12.0
# {'time': datetime.datetime(2022, 8, 7, 2, 11, 55)} 7.0
# {'time': datetime.datetime(2022, 8, 7, 2, 26, 56)} 7.0
# {'time': datetime.datetime(2022, 8, 7, 2, 41, 55)} 16.0
# {'time': datetime.datetime(2022, 8, 7, 2, 56, 56)} 16.0
# {'time': datetime.datetime(2022, 8, 7, 3, 11, 56)} 17.0
# {'time': datetime.datetime(2022, 8, 7, 3, 26, 55)} 43.0
# {'time': datetime.datetime(2022, 8, 7, 3, 41, 56)} 43.0
# {'time': datetime.datetime(2022, 8, 7, 3, 56, 55)} 43.0
# {'time': datetime.datetime(2022, 8, 7, 4, 11, 56)} 41.0
# {'time': datetime.datetime(2022, 8, 7, 4, 26, 55)} 41.0
# {'time': datetime.datetime(2022, 8, 7, 4, 41, 56)} 56.0
# {'time': datetime.datetime(2022, 8, 7, 4, 56, 55)} 56.0
# {'time': datetime.datetime(2022, 8, 7, 5, 11, 56)} 76.0
# {'time': datetime.datetime(2022, 8, 7, 5, 26, 55)} 76.0
# {'time': datetime.datetime(2022, 8, 7, 5, 41, 55)} 50.0
# {'time': datetime.datetime(2022, 8, 7, 5, 56, 55)} 50.0
# {'time': datetime.datetime(2022, 8, 7, 6, 11, 55)} 51.0
# {'time': datetime.datetime(2022, 8, 7, 6, 26, 55)} 51.0
# {'time': datetime.datetime(2022, 8, 7, 6, 41, 55)} 68.0
# {'time': datetime.datetime(2022, 8, 7, 6, 56, 55)} 68.0
# {'time': datetime.datetime(2022, 8, 7, 7, 11, 56)} 69.0
# {'time': datetime.datetime(2022, 8, 7, 7, 26, 55)} 69.0
# {'time': datetime.datetime(2022, 8, 7, 7, 41, 55)} 72.0
# {'time': datetime.datetime(2022, 8, 7, 7, 56, 55)} 134.0
# {'time': datetime.datetime(2022, 8, 7, 8, 11, 55)} 134.0
# {'time': datetime.datetime(2022, 8, 7, 8, 26, 55)} 134.0
# {'time': datetime.datetime(2022, 8, 7, 8, 41, 55)} 225.0
# {'time': datetime.datetime(2022, 8, 7, 8, 56, 55)} 225.0
# {'time': datetime.datetime(2022, 8, 7, 9, 11, 55)} 342.0
# {'time': datetime.datetime(2022, 8, 7, 9, 26, 55)} 342.0
# {'time': datetime.datetime(2022, 8, 7, 9, 41, 56)} 399.0
# {'time': datetime.datetime(2022, 8, 7, 9, 56, 55)} 399.0
# {'time': datetime.datetime(2022, 8, 7, 10, 11, 55)} 361.0
# {'time': datetime.datetime(2022, 8, 7, 10, 26, 55)} 361.0
# {'time': datetime.datetime(2022, 8, 7, 10, 41, 55)} 305.0
# {'time': datetime.datetime(2022, 8, 7, 10, 56, 55)} 305.0
# {'time': datetime.datetime(2022, 8, 7, 11, 11, 56)} 322.0
# {'time': datetime.datetime(2022, 8, 7, 11, 26, 56)} 300.0
# {'time': datetime.datetime(2022, 8, 7, 11, 41, 55)} 300.0
# {'time': datetime.datetime(2022, 8, 7, 11, 56, 56)} 300.0
# {'time': datetime.datetime(2022, 8, 7, 12, 11, 55)} 270.0
# {'time': datetime.datetime(2022, 8, 7, 12, 26, 55)} 270.0
# {'time': datetime.datetime(2022, 8, 7, 12, 41, 56)} 288.0
# {'time': datetime.datetime(2022, 8, 7, 12, 56, 55)} 288.0
# {'time': datetime.datetime(2022, 8, 7, 13, 11, 56)} 313.0
# {'time': datetime.datetime(2022, 8, 7, 13, 26, 56)} 313.0
# {'time': datetime.datetime(2022, 8, 7, 13, 41, 55)} 268.0
# {'time': datetime.datetime(2022, 8, 7, 13, 56, 55)} 268.0
# {'time': datetime.datetime(2022, 8, 7, 14, 11, 56)} 252.0
# {'time': datetime.datetime(2022, 8, 7, 14, 26, 56)} 252.0
# {'time': datetime.datetime(2022, 8, 7, 14, 41, 55)} 271.0
# {'time': datetime.datetime(2022, 8, 7, 14, 56, 56)} 271.0
# {'time': datetime.datetime(2022, 8, 7, 15, 11, 56)} 266.0
# {'time': datetime.datetime(2022, 8, 7, 15, 26, 55)} 266.0
# {'time': datetime.datetime(2022, 8, 7, 15, 41, 56)} 220.0
# {'time': datetime.datetime(2022, 8, 7, 15, 56, 55)} 220.0
# {'time': datetime.datetime(2022, 8, 7, 16, 11, 56)} 197.0
# {'time': datetime.datetime(2022, 8, 7, 16, 26, 55)} 197.0
# {'time': datetime.datetime(2022, 8, 7, 16, 41, 55)} 118.0
# {'time': datetime.datetime(2022, 8, 7, 16, 56, 57)} 118.0
# {'time': datetime.datetime(2022, 8, 7, 17, 11, 56)} 112.0
# {'time': datetime.datetime(2022, 8, 7, 17, 26, 56)} 112.0
# {'time': datetime.datetime(2022, 8, 7, 17, 41, 55)} 287.0
# {'time': datetime.datetime(2022, 8, 7, 17, 56, 56)} 287.0
# {'time': datetime.datetime(2022, 8, 7, 18, 11, 56)} 152.0
# {'time': datetime.datetime(2022, 8, 7, 18, 26, 55)} 152.0
# {'time': datetime.datetime(2022, 8, 7, 18, 41, 56)} 80.0
# {'time': datetime.datetime(2022, 8, 7, 18, 56, 55)} 80.0
# {'time': datetime.datetime(2022, 8, 7, 19, 11, 55)} 77.0
# {'time': datetime.datetime(2022, 8, 7, 19, 26, 55)} 77.0
# {'time': datetime.datetime(2022, 8, 7, 19, 41, 55)} 82.0
# {'time': datetime.datetime(2022, 8, 7, 19, 56, 56)} 82.0
# {'time': datetime.datetime(2022, 8, 7, 20, 11, 56)} 59.0
# {'time': datetime.datetime(2022, 8, 7, 20, 26, 56)} 59.0
# {'time': datetime.datetime(2022, 8, 7, 20, 41, 55)} 56.0
# {'time': datetime.datetime(2022, 8, 7, 20, 56, 55)} 56.0
# {'time': datetime.datetime(2022, 8, 7, 21, 11, 55)} 69.0
# {'time': datetime.datetime(2022, 8, 7, 21, 26, 56)} 69.0
# {'time': datetime.datetime(2022, 8, 7, 21, 41, 56)} 59.0
# {'time': datetime.datetime(2022, 8, 7, 21, 56, 55)} 59.0
# {'time': datetime.datetime(2022, 8, 7, 22, 11, 56)} 49.0
# {'time': datetime.datetime(2022, 8, 7, 22, 26, 55)} 49.0
# {'time': datetime.datetime(2022, 8, 7, 22, 41, 56)} 56.0
# {'time': datetime.datetime(2022, 8, 7, 22, 56, 56)} 56.0
# {'time': datetime.datetime(2022, 8, 7, 23, 11, 56)} 77.0
# {'time': datetime.datetime(2022, 8, 7, 23, 26, 55)} 77.0
# {'time': datetime.datetime(2022, 8, 7, 23, 41, 55)} 96.0
# {'time': datetime.datetime(2022, 8, 7, 23, 56, 56)} 96.0
# {'time': datetime.datetime(2022, 8, 8, 0, 11, 56)} 106.0
# {'time': datetime.datetime(2022, 8, 8, 0, 26, 55)} 106.0
# {'time': datetime.datetime(2022, 8, 8, 0, 41, 55)} 99.0
# {'time': datetime.datetime(2022, 8, 8, 0, 56, 56)} 99.0
# {'time': datetime.datetime(2022, 8, 8, 1, 11, 56)} 93.0
# {'time': datetime.datetime(2022, 8, 8, 1, 26, 55)} 93.0
# {'time': datetime.datetime(2022, 8, 8, 1, 41, 56)} 78.0
# {'time': datetime.datetime(2022, 8, 8, 1, 56, 56)} 78.0
# {'time': datetime.datetime(2022, 8, 8, 2, 11, 56)} 71.0
# {'time': datetime.datetime(2022, 8, 8, 2, 26, 55)} 71.0
# {'time': datetime.datetime(2022, 8, 8, 2, 41, 55)} 76.0
# {'time': datetime.datetime(2022, 8, 8, 2, 56, 55)} 76.0

# %%
from river import compose
from river import linear_model
from river import metrics
from river import evaluate
from river import preprocessing
from river import feature_extraction
from river import stats
from river import optim
from river import facto
from river import model_selection
from river import time_series
from river import tree
from river import dummy

# %%
import math
import datetime
import numpy as np

hour_list = [str(i) for i in range (0,24)]
minute_list = [f'{str(i)} min' for i in range (0, 60)]
def get_hour(x):
    x['h'] = x['time'].hour
    return x
print(get_hour({'time': datetime.datetime(2022, 7, 22, 15, 3, 37)}))

def get_minute(x):
    x['m'] = x['time'].minute//15 + 1
    return x

def get_day(x):
    
    return {'d' : x['time'].day}

def get_hour_sin_and_cos(x):
    x['sin_h'] = np.sin(np.pi*(x['time'].hour)/12) 
    x['cos_h'] = np.cos(np.pi*(x['time'].hour)/12)
    return {'sin_h' : np.sin(np.pi*(x['time'].hour)/12), 'cos_h': np.cos(np.pi*(x['time'].hour)/12)}
print(get_hour_sin_and_cos({'time': datetime.datetime(2022, 7, 22, 6, 3, 37)}))

def get_minute_distances(x):
    x['sin_m'] = np.sin(np.pi*(x['time'].minute)/30)
    x['cos_m'] = np.cos(np.pi*(x['time'].minute)/30)
    return {'sin_m' : np.sin(np.pi*(x['time'].minute)/30), 'cos_m': np.cos(np.pi*(x['time'].minute)/30)}

def get_date_progress(x):
    return {'date': x['time'].toordinal() - datetime.datetime(2022, 1, 1, 0, 0).toordinal()}

i = 0
temp = [323,323,323,323]
cache = [temp]
my_dict = {}
print(cache)
for x, y in stream.iter_csv('hospital_wait.csv', target = 'value', **params):
    print(x)
    if i < 4:
        t = temp.copy()
        t[i] = y
        cache.append(t)      
        temp = t
        my_dict[x['time']] = t
    else:
        t = temp.copy()
        t.pop(0)
        t.append(y)
        cache.append(t)
        temp = t
        my_dict[x['time']] = t
    i += 1

print(my_dict)

def get_lag(x):
    lag_values = my_dict[x['time']]
    return {'lag_1': lag_values[0], 'lag_2': lag_values[1], 'lag_3': lag_values[2], 'lag_4': lag_values[3]}
# Out:
# {'time': datetime.datetime(2022, 7, 22, 15, 3, 37), 'h': 15}
# {'sin_h': 1.0, 'cos_h': 6.123233995736766e-17}
# [[323, 323, 323, 323]]
# {'time': datetime.datetime(2022, 7, 28, 17, 11, 55)}
# {'time': datetime.datetime(2022, 7, 28, 17, 26, 56)}
# {'time': datetime.datetime(2022, 7, 28, 17, 41, 55)}
# {'time': datetime.datetime(2022, 7, 28, 17, 56, 56)}
# {'time': datetime.datetime(2022, 7, 28, 18, 11, 56)}
# {'time': datetime.datetime(2022, 7, 28, 18, 26, 56)}
# {'time': datetime.datetime(2022, 7, 28, 18, 41, 56)}
# {'time': datetime.datetime(2022, 7, 28, 18, 56, 59)}
# {'time': datetime.datetime(2022, 7, 28, 19, 11, 55)}
# {'time': datetime.datetime(2022, 7, 28, 19, 26, 56)}
# {'time': datetime.datetime(2022, 7, 28, 19, 41, 56)}
# {'time': datetime.datetime(2022, 7, 28, 19, 56, 55)}
# {'time': datetime.datetime(2022, 7, 28, 20, 11, 55)}
# {'time': datetime.datetime(2022, 7, 28, 20, 26, 56)}
# {'time': datetime.datetime(2022, 7, 28, 20, 41, 56)}
# {'time': datetime.datetime(2022, 7, 28, 20, 56, 55)}
# {'time': datetime.datetime(2022, 7, 28, 21, 11, 56)}
# {'time': datetime.datetime(2022, 7, 28, 21, 26, 55)}
# {'time': datetime.datetime(2022, 7, 28, 21, 41, 55)}
# {'time': datetime.datetime(2022, 7, 28, 21, 56, 55)}
# {'time': datetime.datetime(2022, 7, 28, 22, 11, 55)}
# {'time': datetime.datetime(2022, 7, 28, 22, 26, 56)}
# {'time': datetime.datetime(2022, 7, 28, 22, 41, 56)}
# {'time': datetime.datetime(2022, 7, 28, 22, 56, 56)}
# {'time': datetime.datetime(2022, 7, 28, 23, 11, 55)}
# {'time': datetime.datetime(2022, 7, 28, 23, 26, 56)}
# {'time': datetime.datetime(2022, 7, 28, 23, 41, 55)}
# {'time': datetime.datetime(2022, 7, 28, 23, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 0, 11, 55)}
# {'time': datetime.datetime(2022, 7, 29, 0, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 0, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 0, 56, 55)}
# {'time': datetime.datetime(2022, 7, 29, 1, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 1, 26, 55)}
# {'time': datetime.datetime(2022, 7, 29, 1, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 1, 56, 55)}
# {'time': datetime.datetime(2022, 7, 29, 2, 11, 55)}
# {'time': datetime.datetime(2022, 7, 29, 2, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 2, 41, 56)}
# {'time': datetime.datetime(2022, 7, 29, 2, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 3, 11, 55)}
# {'time': datetime.datetime(2022, 7, 29, 3, 26, 55)}
# {'time': datetime.datetime(2022, 7, 29, 3, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 3, 56, 55)}
# {'time': datetime.datetime(2022, 7, 29, 4, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 4, 26, 57)}
# {'time': datetime.datetime(2022, 7, 29, 4, 41, 56)}
# {'time': datetime.datetime(2022, 7, 29, 4, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 5, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 5, 26, 55)}
# {'time': datetime.datetime(2022, 7, 29, 5, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 5, 56, 55)}
# {'time': datetime.datetime(2022, 7, 29, 6, 11, 55)}
# {'time': datetime.datetime(2022, 7, 29, 6, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 6, 41, 56)}
# {'time': datetime.datetime(2022, 7, 29, 6, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 7, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 7, 26, 55)}
# {'time': datetime.datetime(2022, 7, 29, 7, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 7, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 8, 11, 55)}
# {'time': datetime.datetime(2022, 7, 29, 8, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 8, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 8, 56, 55)}
# {'time': datetime.datetime(2022, 7, 29, 9, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 9, 26, 55)}
# {'time': datetime.datetime(2022, 7, 29, 9, 41, 56)}
# {'time': datetime.datetime(2022, 7, 29, 9, 56, 55)}
# {'time': datetime.datetime(2022, 7, 29, 10, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 10, 26, 55)}
# {'time': datetime.datetime(2022, 7, 29, 10, 41, 56)}
# {'time': datetime.datetime(2022, 7, 29, 10, 56, 57)}
# {'time': datetime.datetime(2022, 7, 29, 11, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 11, 26, 55)}
# {'time': datetime.datetime(2022, 7, 29, 11, 41, 56)}
# {'time': datetime.datetime(2022, 7, 29, 11, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 12, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 12, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 12, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 12, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 13, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 13, 26, 55)}
# {'time': datetime.datetime(2022, 7, 29, 13, 41, 56)}
# {'time': datetime.datetime(2022, 7, 29, 13, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 14, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 14, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 14, 41, 56)}
# {'time': datetime.datetime(2022, 7, 29, 14, 56, 55)}
# {'time': datetime.datetime(2022, 7, 29, 15, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 15, 26, 55)}
# {'time': datetime.datetime(2022, 7, 29, 15, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 15, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 16, 11, 55)}
# {'time': datetime.datetime(2022, 7, 29, 16, 26, 55)}
# {'time': datetime.datetime(2022, 7, 29, 16, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 16, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 17, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 17, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 17, 41, 56)}
# {'time': datetime.datetime(2022, 7, 29, 17, 56, 55)}
# {'time': datetime.datetime(2022, 7, 29, 18, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 18, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 18, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 18, 56, 55)}
# {'time': datetime.datetime(2022, 7, 29, 19, 11, 57)}
# {'time': datetime.datetime(2022, 7, 29, 19, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 19, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 19, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 20, 11, 55)}
# {'time': datetime.datetime(2022, 7, 29, 20, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 20, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 20, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 21, 11, 55)}
# {'time': datetime.datetime(2022, 7, 29, 21, 26, 55)}
# {'time': datetime.datetime(2022, 7, 29, 21, 41, 56)}
# {'time': datetime.datetime(2022, 7, 29, 21, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 22, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 22, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 22, 41, 56)}
# {'time': datetime.datetime(2022, 7, 29, 22, 56, 56)}
# {'time': datetime.datetime(2022, 7, 29, 23, 11, 56)}
# {'time': datetime.datetime(2022, 7, 29, 23, 26, 56)}
# {'time': datetime.datetime(2022, 7, 29, 23, 41, 55)}
# {'time': datetime.datetime(2022, 7, 29, 23, 56, 56)}
# {'time': datetime.datetime(2022, 7, 30, 0, 11, 56)}
# {'time': datetime.datetime(2022, 7, 30, 0, 26, 56)}
# {'time': datetime.datetime(2022, 7, 30, 0, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 0, 56, 56)}
# {'time': datetime.datetime(2022, 7, 30, 1, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 1, 26, 56)}
# {'time': datetime.datetime(2022, 7, 30, 1, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 1, 56, 56)}
# {'time': datetime.datetime(2022, 7, 30, 2, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 2, 26, 56)}
# {'time': datetime.datetime(2022, 7, 30, 2, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 2, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 3, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 3, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 3, 41, 56)}
# {'time': datetime.datetime(2022, 7, 30, 3, 56, 56)}
# {'time': datetime.datetime(2022, 7, 30, 4, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 4, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 4, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 4, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 5, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 5, 26, 56)}
# {'time': datetime.datetime(2022, 7, 30, 5, 41, 56)}
# {'time': datetime.datetime(2022, 7, 30, 5, 56, 56)}
# {'time': datetime.datetime(2022, 7, 30, 6, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 6, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 6, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 6, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 7, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 7, 26, 56)}
# {'time': datetime.datetime(2022, 7, 30, 7, 41, 56)}
# {'time': datetime.datetime(2022, 7, 30, 7, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 8, 11, 56)}
# {'time': datetime.datetime(2022, 7, 30, 8, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 8, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 8, 56, 56)}
# {'time': datetime.datetime(2022, 7, 30, 9, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 9, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 9, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 9, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 10, 11, 56)}
# {'time': datetime.datetime(2022, 7, 30, 10, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 10, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 10, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 11, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 11, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 11, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 11, 56, 56)}
# {'time': datetime.datetime(2022, 7, 30, 12, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 12, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 12, 41, 56)}
# {'time': datetime.datetime(2022, 7, 30, 12, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 13, 11, 56)}
# {'time': datetime.datetime(2022, 7, 30, 13, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 13, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 13, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 14, 11, 56)}
# {'time': datetime.datetime(2022, 7, 30, 14, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 14, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 14, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 15, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 15, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 15, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 15, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 16, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 16, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 16, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 16, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 17, 11, 56)}
# {'time': datetime.datetime(2022, 7, 30, 17, 26, 56)}
# {'time': datetime.datetime(2022, 7, 30, 17, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 17, 56, 56)}
# {'time': datetime.datetime(2022, 7, 30, 18, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 18, 26, 56)}
# {'time': datetime.datetime(2022, 7, 30, 18, 41, 56)}
# {'time': datetime.datetime(2022, 7, 30, 18, 56, 56)}
# {'time': datetime.datetime(2022, 7, 30, 19, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 19, 26, 56)}
# {'time': datetime.datetime(2022, 7, 30, 19, 41, 56)}
# {'time': datetime.datetime(2022, 7, 30, 19, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 20, 11, 56)}
# {'time': datetime.datetime(2022, 7, 30, 20, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 20, 41, 56)}
# {'time': datetime.datetime(2022, 7, 30, 20, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 21, 11, 56)}
# {'time': datetime.datetime(2022, 7, 30, 21, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 21, 41, 56)}
# {'time': datetime.datetime(2022, 7, 30, 21, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 22, 11, 55)}
# {'time': datetime.datetime(2022, 7, 30, 22, 26, 55)}
# {'time': datetime.datetime(2022, 7, 30, 22, 41, 55)}
# {'time': datetime.datetime(2022, 7, 30, 22, 56, 55)}
# {'time': datetime.datetime(2022, 7, 30, 23, 11, 56)}
# {'time': datetime.datetime(2022, 7, 30, 23, 26, 56)}
# {'time': datetime.datetime(2022, 7, 30, 23, 41, 56)}
# {'time': datetime.datetime(2022, 7, 30, 23, 56, 56)}
# {'time': datetime.datetime(2022, 7, 31, 0, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 0, 26, 56)}
# {'time': datetime.datetime(2022, 7, 31, 0, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 0, 56, 56)}
# {'time': datetime.datetime(2022, 7, 31, 1, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 1, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 1, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 1, 56, 56)}
# {'time': datetime.datetime(2022, 7, 31, 2, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 2, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 2, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 2, 56, 56)}
# {'time': datetime.datetime(2022, 7, 31, 3, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 3, 26, 56)}
# {'time': datetime.datetime(2022, 7, 31, 3, 41, 56)}
# {'time': datetime.datetime(2022, 7, 31, 3, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 4, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 4, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 4, 41, 56)}
# {'time': datetime.datetime(2022, 7, 31, 4, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 5, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 5, 26, 56)}
# {'time': datetime.datetime(2022, 7, 31, 5, 41, 56)}
# {'time': datetime.datetime(2022, 7, 31, 5, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 6, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 6, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 6, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 6, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 7, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 7, 26, 56)}
# {'time': datetime.datetime(2022, 7, 31, 7, 41, 56)}
# {'time': datetime.datetime(2022, 7, 31, 7, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 8, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 8, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 8, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 8, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 9, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 9, 26, 56)}
# {'time': datetime.datetime(2022, 7, 31, 9, 41, 56)}
# {'time': datetime.datetime(2022, 7, 31, 9, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 10, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 10, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 10, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 10, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 11, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 11, 26, 56)}
# {'time': datetime.datetime(2022, 7, 31, 11, 41, 56)}
# {'time': datetime.datetime(2022, 7, 31, 11, 56, 56)}
# {'time': datetime.datetime(2022, 7, 31, 12, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 12, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 12, 41, 56)}
# {'time': datetime.datetime(2022, 7, 31, 12, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 13, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 13, 26, 56)}
# {'time': datetime.datetime(2022, 7, 31, 13, 41, 56)}
# {'time': datetime.datetime(2022, 7, 31, 13, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 14, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 14, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 14, 41, 56)}
# {'time': datetime.datetime(2022, 7, 31, 14, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 15, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 15, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 15, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 15, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 16, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 16, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 16, 41, 56)}
# {'time': datetime.datetime(2022, 7, 31, 16, 56, 56)}
# {'time': datetime.datetime(2022, 7, 31, 17, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 17, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 17, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 17, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 18, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 18, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 18, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 18, 56, 56)}
# {'time': datetime.datetime(2022, 7, 31, 19, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 19, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 19, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 19, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 20, 11, 55)}
# {'time': datetime.datetime(2022, 7, 31, 20, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 20, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 20, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 21, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 21, 26, 56)}
# {'time': datetime.datetime(2022, 7, 31, 21, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 21, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 22, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 22, 26, 56)}
# {'time': datetime.datetime(2022, 7, 31, 22, 41, 56)}
# {'time': datetime.datetime(2022, 7, 31, 22, 56, 55)}
# {'time': datetime.datetime(2022, 7, 31, 23, 11, 56)}
# {'time': datetime.datetime(2022, 7, 31, 23, 26, 55)}
# {'time': datetime.datetime(2022, 7, 31, 23, 41, 55)}
# {'time': datetime.datetime(2022, 7, 31, 23, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 0, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 0, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 0, 41, 56)}
# {'time': datetime.datetime(2022, 8, 1, 0, 56, 55)}
# {'time': datetime.datetime(2022, 8, 1, 1, 11, 56)}
# {'time': datetime.datetime(2022, 8, 1, 1, 26, 56)}
# {'time': datetime.datetime(2022, 8, 1, 1, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 1, 56, 55)}
# {'time': datetime.datetime(2022, 8, 1, 2, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 2, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 2, 41, 56)}
# {'time': datetime.datetime(2022, 8, 1, 2, 56, 55)}
# {'time': datetime.datetime(2022, 8, 1, 3, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 3, 26, 56)}
# {'time': datetime.datetime(2022, 8, 1, 3, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 3, 56, 55)}
# {'time': datetime.datetime(2022, 8, 1, 4, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 4, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 4, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 4, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 5, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 5, 26, 56)}
# {'time': datetime.datetime(2022, 8, 1, 5, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 5, 56, 55)}
# {'time': datetime.datetime(2022, 8, 1, 6, 11, 56)}
# {'time': datetime.datetime(2022, 8, 1, 6, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 6, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 6, 56, 55)}
# {'time': datetime.datetime(2022, 8, 1, 7, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 7, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 7, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 7, 56, 55)}
# {'time': datetime.datetime(2022, 8, 1, 8, 11, 56)}
# {'time': datetime.datetime(2022, 8, 1, 8, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 8, 41, 56)}
# {'time': datetime.datetime(2022, 8, 1, 8, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 9, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 9, 26, 56)}
# {'time': datetime.datetime(2022, 8, 1, 9, 41, 56)}
# {'time': datetime.datetime(2022, 8, 1, 9, 56, 55)}
# {'time': datetime.datetime(2022, 8, 1, 10, 11, 56)}
# {'time': datetime.datetime(2022, 8, 1, 10, 26, 56)}
# {'time': datetime.datetime(2022, 8, 1, 10, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 10, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 11, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 11, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 11, 41, 56)}
# {'time': datetime.datetime(2022, 8, 1, 11, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 12, 11, 56)}
# {'time': datetime.datetime(2022, 8, 1, 12, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 12, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 12, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 13, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 13, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 13, 41, 56)}
# {'time': datetime.datetime(2022, 8, 1, 13, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 14, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 14, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 14, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 14, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 15, 11, 56)}
# {'time': datetime.datetime(2022, 8, 1, 15, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 15, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 15, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 16, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 16, 26, 56)}
# {'time': datetime.datetime(2022, 8, 1, 16, 41, 56)}
# {'time': datetime.datetime(2022, 8, 1, 16, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 17, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 17, 26, 56)}
# {'time': datetime.datetime(2022, 8, 1, 17, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 17, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 18, 11, 56)}
# {'time': datetime.datetime(2022, 8, 1, 18, 26, 56)}
# {'time': datetime.datetime(2022, 8, 1, 18, 41, 56)}
# {'time': datetime.datetime(2022, 8, 1, 18, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 19, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 19, 26, 56)}
# {'time': datetime.datetime(2022, 8, 1, 19, 41, 56)}
# {'time': datetime.datetime(2022, 8, 1, 19, 56, 55)}
# {'time': datetime.datetime(2022, 8, 1, 20, 11, 56)}
# {'time': datetime.datetime(2022, 8, 1, 20, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 20, 41, 56)}
# {'time': datetime.datetime(2022, 8, 1, 20, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 21, 11, 56)}
# {'time': datetime.datetime(2022, 8, 1, 21, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 21, 41, 56)}
# {'time': datetime.datetime(2022, 8, 1, 21, 56, 56)}
# {'time': datetime.datetime(2022, 8, 1, 22, 11, 56)}
# {'time': datetime.datetime(2022, 8, 1, 22, 26, 55)}
# {'time': datetime.datetime(2022, 8, 1, 22, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 22, 56, 55)}
# {'time': datetime.datetime(2022, 8, 1, 23, 11, 55)}
# {'time': datetime.datetime(2022, 8, 1, 23, 26, 56)}
# {'time': datetime.datetime(2022, 8, 1, 23, 41, 55)}
# {'time': datetime.datetime(2022, 8, 1, 23, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 0, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 0, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 0, 41, 55)}
# {'time': datetime.datetime(2022, 8, 2, 0, 56, 57)}
# {'time': datetime.datetime(2022, 8, 2, 1, 11, 55)}
# {'time': datetime.datetime(2022, 8, 2, 1, 26, 55)}
# {'time': datetime.datetime(2022, 8, 2, 1, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 1, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 2, 11, 55)}
# {'time': datetime.datetime(2022, 8, 2, 2, 26, 55)}
# {'time': datetime.datetime(2022, 8, 2, 2, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 2, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 3, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 3, 26, 55)}
# {'time': datetime.datetime(2022, 8, 2, 3, 41, 55)}
# {'time': datetime.datetime(2022, 8, 2, 3, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 4, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 4, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 4, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 4, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 5, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 5, 26, 55)}
# {'time': datetime.datetime(2022, 8, 2, 5, 41, 55)}
# {'time': datetime.datetime(2022, 8, 2, 5, 56, 56)}
# {'time': datetime.datetime(2022, 8, 2, 6, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 6, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 6, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 6, 56, 56)}
# {'time': datetime.datetime(2022, 8, 2, 7, 11, 55)}
# {'time': datetime.datetime(2022, 8, 2, 7, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 7, 41, 55)}
# {'time': datetime.datetime(2022, 8, 2, 7, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 8, 11, 55)}
# {'time': datetime.datetime(2022, 8, 2, 8, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 8, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 8, 56, 56)}
# {'time': datetime.datetime(2022, 8, 2, 9, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 9, 26, 55)}
# {'time': datetime.datetime(2022, 8, 2, 9, 41, 55)}
# {'time': datetime.datetime(2022, 8, 2, 9, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 10, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 10, 26, 55)}
# {'time': datetime.datetime(2022, 8, 2, 10, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 10, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 11, 11, 55)}
# {'time': datetime.datetime(2022, 8, 2, 11, 26, 55)}
# {'time': datetime.datetime(2022, 8, 2, 11, 41, 55)}
# {'time': datetime.datetime(2022, 8, 2, 11, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 12, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 12, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 12, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 12, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 13, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 13, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 13, 41, 55)}
# {'time': datetime.datetime(2022, 8, 2, 13, 56, 56)}
# {'time': datetime.datetime(2022, 8, 2, 14, 11, 55)}
# {'time': datetime.datetime(2022, 8, 2, 14, 26, 55)}
# {'time': datetime.datetime(2022, 8, 2, 14, 41, 55)}
# {'time': datetime.datetime(2022, 8, 2, 14, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 15, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 15, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 15, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 15, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 16, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 16, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 16, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 16, 56, 56)}
# {'time': datetime.datetime(2022, 8, 2, 17, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 17, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 17, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 17, 56, 56)}
# {'time': datetime.datetime(2022, 8, 2, 18, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 18, 26, 55)}
# {'time': datetime.datetime(2022, 8, 2, 18, 41, 55)}
# {'time': datetime.datetime(2022, 8, 2, 18, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 19, 11, 55)}
# {'time': datetime.datetime(2022, 8, 2, 19, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 19, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 19, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 20, 11, 55)}
# {'time': datetime.datetime(2022, 8, 2, 20, 26, 55)}
# {'time': datetime.datetime(2022, 8, 2, 20, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 20, 56, 56)}
# {'time': datetime.datetime(2022, 8, 2, 21, 11, 55)}
# {'time': datetime.datetime(2022, 8, 2, 21, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 21, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 21, 56, 56)}
# {'time': datetime.datetime(2022, 8, 2, 22, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 22, 26, 55)}
# {'time': datetime.datetime(2022, 8, 2, 22, 41, 56)}
# {'time': datetime.datetime(2022, 8, 2, 22, 56, 55)}
# {'time': datetime.datetime(2022, 8, 2, 23, 11, 56)}
# {'time': datetime.datetime(2022, 8, 2, 23, 26, 56)}
# {'time': datetime.datetime(2022, 8, 2, 23, 41, 55)}
# {'time': datetime.datetime(2022, 8, 2, 23, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 0, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 0, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 0, 41, 55)}
# {'time': datetime.datetime(2022, 8, 3, 0, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 1, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 1, 26, 56)}
# {'time': datetime.datetime(2022, 8, 3, 1, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 1, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 2, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 2, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 2, 41, 55)}
# {'time': datetime.datetime(2022, 8, 3, 2, 56, 56)}
# {'time': datetime.datetime(2022, 8, 3, 3, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 3, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 3, 41, 55)}
# {'time': datetime.datetime(2022, 8, 3, 3, 56, 56)}
# {'time': datetime.datetime(2022, 8, 3, 4, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 4, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 4, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 4, 56, 56)}
# {'time': datetime.datetime(2022, 8, 3, 5, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 5, 26, 56)}
# {'time': datetime.datetime(2022, 8, 3, 5, 41, 55)}
# {'time': datetime.datetime(2022, 8, 3, 5, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 6, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 6, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 6, 41, 55)}
# {'time': datetime.datetime(2022, 8, 3, 6, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 7, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 7, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 7, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 7, 56, 56)}
# {'time': datetime.datetime(2022, 8, 3, 8, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 8, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 8, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 8, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 9, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 9, 26, 56)}
# {'time': datetime.datetime(2022, 8, 3, 9, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 9, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 10, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 10, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 10, 41, 55)}
# {'time': datetime.datetime(2022, 8, 3, 10, 56, 57)}
# {'time': datetime.datetime(2022, 8, 3, 11, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 11, 26, 56)}
# {'time': datetime.datetime(2022, 8, 3, 11, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 11, 56, 56)}
# {'time': datetime.datetime(2022, 8, 3, 12, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 12, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 12, 41, 55)}
# {'time': datetime.datetime(2022, 8, 3, 12, 56, 56)}
# {'time': datetime.datetime(2022, 8, 3, 13, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 13, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 13, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 13, 56, 56)}
# {'time': datetime.datetime(2022, 8, 3, 14, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 14, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 14, 41, 55)}
# {'time': datetime.datetime(2022, 8, 3, 14, 56, 56)}
# {'time': datetime.datetime(2022, 8, 3, 15, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 15, 26, 56)}
# {'time': datetime.datetime(2022, 8, 3, 15, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 15, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 16, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 16, 26, 56)}
# {'time': datetime.datetime(2022, 8, 3, 16, 41, 55)}
# {'time': datetime.datetime(2022, 8, 3, 16, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 17, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 17, 26, 56)}
# {'time': datetime.datetime(2022, 8, 3, 17, 41, 55)}
# {'time': datetime.datetime(2022, 8, 3, 17, 56, 56)}
# {'time': datetime.datetime(2022, 8, 3, 18, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 18, 26, 56)}
# {'time': datetime.datetime(2022, 8, 3, 18, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 18, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 19, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 19, 26, 56)}
# {'time': datetime.datetime(2022, 8, 3, 19, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 19, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 20, 11, 56)}
# {'time': datetime.datetime(2022, 8, 3, 20, 26, 56)}
# {'time': datetime.datetime(2022, 8, 3, 20, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 20, 56, 56)}
# {'time': datetime.datetime(2022, 8, 3, 21, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 21, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 21, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 21, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 22, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 22, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 22, 41, 55)}
# {'time': datetime.datetime(2022, 8, 3, 22, 56, 55)}
# {'time': datetime.datetime(2022, 8, 3, 23, 11, 55)}
# {'time': datetime.datetime(2022, 8, 3, 23, 26, 55)}
# {'time': datetime.datetime(2022, 8, 3, 23, 41, 56)}
# {'time': datetime.datetime(2022, 8, 3, 23, 56, 56)}
# {'time': datetime.datetime(2022, 8, 4, 0, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 0, 26, 55)}
# {'time': datetime.datetime(2022, 8, 4, 0, 41, 56)}
# {'time': datetime.datetime(2022, 8, 4, 0, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 1, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 1, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 1, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 1, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 2, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 2, 26, 55)}
# {'time': datetime.datetime(2022, 8, 4, 2, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 2, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 3, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 3, 26, 55)}
# {'time': datetime.datetime(2022, 8, 4, 3, 41, 56)}
# {'time': datetime.datetime(2022, 8, 4, 3, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 4, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 4, 26, 55)}
# {'time': datetime.datetime(2022, 8, 4, 4, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 4, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 5, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 5, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 5, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 5, 56, 56)}
# {'time': datetime.datetime(2022, 8, 4, 6, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 6, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 6, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 6, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 7, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 7, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 7, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 7, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 8, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 8, 26, 55)}
# {'time': datetime.datetime(2022, 8, 4, 8, 41, 56)}
# {'time': datetime.datetime(2022, 8, 4, 8, 56, 56)}
# {'time': datetime.datetime(2022, 8, 4, 9, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 9, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 9, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 9, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 10, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 10, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 10, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 10, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 11, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 11, 26, 55)}
# {'time': datetime.datetime(2022, 8, 4, 11, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 11, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 12, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 12, 26, 55)}
# {'time': datetime.datetime(2022, 8, 4, 12, 41, 56)}
# {'time': datetime.datetime(2022, 8, 4, 12, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 13, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 13, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 13, 41, 56)}
# {'time': datetime.datetime(2022, 8, 4, 13, 56, 56)}
# {'time': datetime.datetime(2022, 8, 4, 14, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 14, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 14, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 14, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 15, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 15, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 15, 41, 56)}
# {'time': datetime.datetime(2022, 8, 4, 15, 56, 56)}
# {'time': datetime.datetime(2022, 8, 4, 16, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 16, 26, 55)}
# {'time': datetime.datetime(2022, 8, 4, 16, 41, 56)}
# {'time': datetime.datetime(2022, 8, 4, 16, 56, 56)}
# {'time': datetime.datetime(2022, 8, 4, 17, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 17, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 17, 41, 56)}
# {'time': datetime.datetime(2022, 8, 4, 17, 56, 57)}
# {'time': datetime.datetime(2022, 8, 4, 18, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 18, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 18, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 18, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 19, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 19, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 19, 41, 56)}
# {'time': datetime.datetime(2022, 8, 4, 19, 56, 56)}
# {'time': datetime.datetime(2022, 8, 4, 20, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 20, 26, 55)}
# {'time': datetime.datetime(2022, 8, 4, 20, 41, 56)}
# {'time': datetime.datetime(2022, 8, 4, 20, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 21, 11, 55)}
# {'time': datetime.datetime(2022, 8, 4, 21, 26, 55)}
# {'time': datetime.datetime(2022, 8, 4, 21, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 21, 56, 55)}
# {'time': datetime.datetime(2022, 8, 4, 22, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 22, 26, 55)}
# {'time': datetime.datetime(2022, 8, 4, 22, 41, 56)}
# {'time': datetime.datetime(2022, 8, 4, 22, 56, 56)}
# {'time': datetime.datetime(2022, 8, 4, 23, 11, 56)}
# {'time': datetime.datetime(2022, 8, 4, 23, 26, 56)}
# {'time': datetime.datetime(2022, 8, 4, 23, 41, 55)}
# {'time': datetime.datetime(2022, 8, 4, 23, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 0, 11, 55)}
# {'time': datetime.datetime(2022, 8, 5, 0, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 0, 41, 55)}
# {'time': datetime.datetime(2022, 8, 5, 0, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 1, 11, 55)}
# {'time': datetime.datetime(2022, 8, 5, 1, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 1, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 1, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 2, 11, 55)}
# {'time': datetime.datetime(2022, 8, 5, 2, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 2, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 2, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 3, 11, 55)}
# {'time': datetime.datetime(2022, 8, 5, 3, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 3, 41, 55)}
# {'time': datetime.datetime(2022, 8, 5, 3, 56, 55)}
# {'time': datetime.datetime(2022, 8, 5, 4, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 4, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 4, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 4, 56, 55)}
# {'time': datetime.datetime(2022, 8, 5, 5, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 5, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 5, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 5, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 6, 11, 55)}
# {'time': datetime.datetime(2022, 8, 5, 6, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 6, 41, 55)}
# {'time': datetime.datetime(2022, 8, 5, 6, 56, 55)}
# {'time': datetime.datetime(2022, 8, 5, 7, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 7, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 7, 41, 55)}
# {'time': datetime.datetime(2022, 8, 5, 7, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 8, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 8, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 8, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 8, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 9, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 9, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 9, 41, 55)}
# {'time': datetime.datetime(2022, 8, 5, 9, 56, 55)}
# {'time': datetime.datetime(2022, 8, 5, 10, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 10, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 10, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 10, 56, 55)}
# {'time': datetime.datetime(2022, 8, 5, 11, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 11, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 11, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 11, 56, 55)}
# {'time': datetime.datetime(2022, 8, 5, 12, 11, 55)}
# {'time': datetime.datetime(2022, 8, 5, 12, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 12, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 12, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 13, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 13, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 13, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 13, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 14, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 14, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 14, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 14, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 15, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 15, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 15, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 15, 56, 55)}
# {'time': datetime.datetime(2022, 8, 5, 16, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 16, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 16, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 16, 56, 55)}
# {'time': datetime.datetime(2022, 8, 5, 17, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 17, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 17, 41, 55)}
# {'time': datetime.datetime(2022, 8, 5, 17, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 18, 11, 55)}
# {'time': datetime.datetime(2022, 8, 5, 18, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 18, 41, 55)}
# {'time': datetime.datetime(2022, 8, 5, 18, 56, 55)}
# {'time': datetime.datetime(2022, 8, 5, 19, 11, 55)}
# {'time': datetime.datetime(2022, 8, 5, 19, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 19, 41, 55)}
# {'time': datetime.datetime(2022, 8, 5, 19, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 20, 11, 55)}
# {'time': datetime.datetime(2022, 8, 5, 20, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 20, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 20, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 21, 11, 55)}
# {'time': datetime.datetime(2022, 8, 5, 21, 26, 56)}
# {'time': datetime.datetime(2022, 8, 5, 21, 41, 55)}
# {'time': datetime.datetime(2022, 8, 5, 21, 56, 56)}
# {'time': datetime.datetime(2022, 8, 5, 22, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 22, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 22, 41, 55)}
# {'time': datetime.datetime(2022, 8, 5, 22, 56, 55)}
# {'time': datetime.datetime(2022, 8, 5, 23, 11, 56)}
# {'time': datetime.datetime(2022, 8, 5, 23, 26, 55)}
# {'time': datetime.datetime(2022, 8, 5, 23, 41, 56)}
# {'time': datetime.datetime(2022, 8, 5, 23, 56, 55)}
# {'time': datetime.datetime(2022, 8, 6, 0, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 0, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 0, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 0, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 1, 11, 55)}
# {'time': datetime.datetime(2022, 8, 6, 1, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 1, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 1, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 2, 11, 55)}
# {'time': datetime.datetime(2022, 8, 6, 2, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 2, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 2, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 3, 11, 55)}
# {'time': datetime.datetime(2022, 8, 6, 3, 26, 56)}
# {'time': datetime.datetime(2022, 8, 6, 3, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 3, 56, 55)}
# {'time': datetime.datetime(2022, 8, 6, 4, 11, 55)}
# {'time': datetime.datetime(2022, 8, 6, 4, 30, 21)}
# {'time': datetime.datetime(2022, 8, 6, 4, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 4, 56, 55)}
# {'time': datetime.datetime(2022, 8, 6, 5, 11, 55)}
# {'time': datetime.datetime(2022, 8, 6, 5, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 5, 41, 55)}
# {'time': datetime.datetime(2022, 8, 6, 5, 56, 55)}
# {'time': datetime.datetime(2022, 8, 6, 6, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 6, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 6, 41, 55)}
# {'time': datetime.datetime(2022, 8, 6, 6, 56, 55)}
# {'time': datetime.datetime(2022, 8, 6, 7, 11, 55)}
# {'time': datetime.datetime(2022, 8, 6, 7, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 7, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 7, 56, 55)}
# {'time': datetime.datetime(2022, 8, 6, 8, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 8, 26, 56)}
# {'time': datetime.datetime(2022, 8, 6, 8, 41, 55)}
# {'time': datetime.datetime(2022, 8, 6, 8, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 9, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 9, 26, 56)}
# {'time': datetime.datetime(2022, 8, 6, 9, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 9, 56, 55)}
# {'time': datetime.datetime(2022, 8, 6, 10, 11, 55)}
# {'time': datetime.datetime(2022, 8, 6, 10, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 10, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 10, 56, 55)}
# {'time': datetime.datetime(2022, 8, 6, 11, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 11, 26, 56)}
# {'time': datetime.datetime(2022, 8, 6, 11, 41, 55)}
# {'time': datetime.datetime(2022, 8, 6, 11, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 12, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 12, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 12, 41, 55)}
# {'time': datetime.datetime(2022, 8, 6, 12, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 13, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 13, 26, 56)}
# {'time': datetime.datetime(2022, 8, 6, 13, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 13, 56, 55)}
# {'time': datetime.datetime(2022, 8, 6, 14, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 14, 26, 56)}
# {'time': datetime.datetime(2022, 8, 6, 14, 41, 57)}
# {'time': datetime.datetime(2022, 8, 6, 14, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 15, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 15, 26, 56)}
# {'time': datetime.datetime(2022, 8, 6, 15, 41, 55)}
# {'time': datetime.datetime(2022, 8, 6, 15, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 16, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 16, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 16, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 16, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 17, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 17, 26, 56)}
# {'time': datetime.datetime(2022, 8, 6, 17, 41, 55)}
# {'time': datetime.datetime(2022, 8, 6, 17, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 18, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 18, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 18, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 18, 56, 55)}
# {'time': datetime.datetime(2022, 8, 6, 19, 11, 55)}
# {'time': datetime.datetime(2022, 8, 6, 19, 26, 56)}
# {'time': datetime.datetime(2022, 8, 6, 19, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 19, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 20, 11, 55)}
# {'time': datetime.datetime(2022, 8, 6, 20, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 20, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 20, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 21, 11, 55)}
# {'time': datetime.datetime(2022, 8, 6, 21, 26, 55)}
# {'time': datetime.datetime(2022, 8, 6, 21, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 21, 56, 55)}
# {'time': datetime.datetime(2022, 8, 6, 22, 11, 56)}
# {'time': datetime.datetime(2022, 8, 6, 22, 26, 56)}
# {'time': datetime.datetime(2022, 8, 6, 22, 41, 56)}
# {'time': datetime.datetime(2022, 8, 6, 22, 56, 56)}
# {'time': datetime.datetime(2022, 8, 6, 23, 11, 55)}
# {'time': datetime.datetime(2022, 8, 6, 23, 26, 56)}
# {'time': datetime.datetime(2022, 8, 6, 23, 41, 55)}
# {'time': datetime.datetime(2022, 8, 6, 23, 56, 56)}
# {'time': datetime.datetime(2022, 8, 7, 0, 11, 55)}
# {'time': datetime.datetime(2022, 8, 7, 0, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 0, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 0, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 1, 11, 55)}
# {'time': datetime.datetime(2022, 8, 7, 1, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 1, 41, 56)}
# {'time': datetime.datetime(2022, 8, 7, 1, 56, 56)}
# {'time': datetime.datetime(2022, 8, 7, 2, 11, 55)}
# {'time': datetime.datetime(2022, 8, 7, 2, 26, 56)}
# {'time': datetime.datetime(2022, 8, 7, 2, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 2, 56, 56)}
# {'time': datetime.datetime(2022, 8, 7, 3, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 3, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 3, 41, 56)}
# {'time': datetime.datetime(2022, 8, 7, 3, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 4, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 4, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 4, 41, 56)}
# {'time': datetime.datetime(2022, 8, 7, 4, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 5, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 5, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 5, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 5, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 6, 11, 55)}
# {'time': datetime.datetime(2022, 8, 7, 6, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 6, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 6, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 7, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 7, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 7, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 7, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 8, 11, 55)}
# {'time': datetime.datetime(2022, 8, 7, 8, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 8, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 8, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 9, 11, 55)}
# {'time': datetime.datetime(2022, 8, 7, 9, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 9, 41, 56)}
# {'time': datetime.datetime(2022, 8, 7, 9, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 10, 11, 55)}
# {'time': datetime.datetime(2022, 8, 7, 10, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 10, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 10, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 11, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 11, 26, 56)}
# {'time': datetime.datetime(2022, 8, 7, 11, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 11, 56, 56)}
# {'time': datetime.datetime(2022, 8, 7, 12, 11, 55)}
# {'time': datetime.datetime(2022, 8, 7, 12, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 12, 41, 56)}
# {'time': datetime.datetime(2022, 8, 7, 12, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 13, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 13, 26, 56)}
# {'time': datetime.datetime(2022, 8, 7, 13, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 13, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 14, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 14, 26, 56)}
# {'time': datetime.datetime(2022, 8, 7, 14, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 14, 56, 56)}
# {'time': datetime.datetime(2022, 8, 7, 15, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 15, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 15, 41, 56)}
# {'time': datetime.datetime(2022, 8, 7, 15, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 16, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 16, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 16, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 16, 56, 57)}
# {'time': datetime.datetime(2022, 8, 7, 17, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 17, 26, 56)}
# {'time': datetime.datetime(2022, 8, 7, 17, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 17, 56, 56)}
# {'time': datetime.datetime(2022, 8, 7, 18, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 18, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 18, 41, 56)}
# {'time': datetime.datetime(2022, 8, 7, 18, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 19, 11, 55)}
# {'time': datetime.datetime(2022, 8, 7, 19, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 19, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 19, 56, 56)}
# {'time': datetime.datetime(2022, 8, 7, 20, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 20, 26, 56)}
# {'time': datetime.datetime(2022, 8, 7, 20, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 20, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 21, 11, 55)}
# {'time': datetime.datetime(2022, 8, 7, 21, 26, 56)}
# {'time': datetime.datetime(2022, 8, 7, 21, 41, 56)}
# {'time': datetime.datetime(2022, 8, 7, 21, 56, 55)}
# {'time': datetime.datetime(2022, 8, 7, 22, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 22, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 22, 41, 56)}
# {'time': datetime.datetime(2022, 8, 7, 22, 56, 56)}
# {'time': datetime.datetime(2022, 8, 7, 23, 11, 56)}
# {'time': datetime.datetime(2022, 8, 7, 23, 26, 55)}
# {'time': datetime.datetime(2022, 8, 7, 23, 41, 55)}
# {'time': datetime.datetime(2022, 8, 7, 23, 56, 56)}
# {'time': datetime.datetime(2022, 8, 8, 0, 11, 56)}
# {'time': datetime.datetime(2022, 8, 8, 0, 26, 55)}
# {'time': datetime.datetime(2022, 8, 8, 0, 41, 55)}
# {'time': datetime.datetime(2022, 8, 8, 0, 56, 56)}
# {'time': datetime.datetime(2022, 8, 8, 1, 11, 56)}
# {'time': datetime.datetime(2022, 8, 8, 1, 26, 55)}
# {'time': datetime.datetime(2022, 8, 8, 1, 41, 56)}
# {'time': datetime.datetime(2022, 8, 8, 1, 56, 56)}
# {'time': datetime.datetime(2022, 8, 8, 2, 11, 56)}
# {'time': datetime.datetime(2022, 8, 8, 2, 26, 55)}
# {'time': datetime.datetime(2022, 8, 8, 2, 41, 55)}
# {'time': datetime.datetime(2022, 8, 8, 2, 56, 55)}
# {datetime.datetime(2022, 7, 28, 17, 11, 55): [323.0, 323, 323, 323], datetime.datetime(2022, 7, 28, 17, 26, 56): [323.0, 323.0, 323, 323], datetime.datetime(2022, 7, 28, 17, 41, 55): [323.0, 323.0, 275.0, 323], datetime.datetime(2022, 7, 28, 17, 56, 56): [323.0, 323.0, 275.0, 275.0], datetime.datetime(2022, 7, 28, 18, 11, 56): [323.0, 275.0, 275.0, 235.0], datetime.datetime(2022, 7, 28, 18, 26, 56): [275.0, 275.0, 235.0, 235.0], datetime.datetime(2022, 7, 28, 18, 41, 56): [275.0, 235.0, 235.0, 241.0], datetime.datetime(2022, 7, 28, 18, 56, 59): [235.0, 235.0, 241.0, 241.0], datetime.datetime(2022, 7, 28, 19, 11, 55): [235.0, 241.0, 241.0, 273.0], datetime.datetime(2022, 7, 28, 19, 26, 56): [241.0, 241.0, 273.0, 273.0], datetime.datetime(2022, 7, 28, 19, 41, 56): [241.0, 273.0, 273.0, 241.0], datetime.datetime(2022, 7, 28, 19, 56, 55): [273.0, 273.0, 241.0, 241.0], datetime.datetime(2022, 7, 28, 20, 11, 55): [273.0, 241.0, 241.0, 221.0], datetime.datetime(2022, 7, 28, 20, 26, 56): [241.0, 241.0, 221.0, 221.0], datetime.datetime(2022, 7, 28, 20, 41, 56): [241.0, 221.0, 221.0, 288.0], datetime.datetime(2022, 7, 28, 20, 56, 55): [221.0, 221.0, 288.0, 288.0], datetime.datetime(2022, 7, 28, 21, 11, 56): [221.0, 288.0, 288.0, 243.0], datetime.datetime(2022, 7, 28, 21, 26, 55): [288.0, 288.0, 243.0, 243.0], datetime.datetime(2022, 7, 28, 21, 41, 55): [288.0, 243.0, 243.0, 204.0], datetime.datetime(2022, 7, 28, 21, 56, 55): [243.0, 243.0, 204.0, 204.0], datetime.datetime(2022, 7, 28, 22, 11, 55): [243.0, 204.0, 204.0, 201.0], datetime.datetime(2022, 7, 28, 22, 26, 56): [204.0, 204.0, 201.0, 201.0], datetime.datetime(2022, 7, 28, 22, 41, 56): [204.0, 201.0, 201.0, 261.0], datetime.datetime(2022, 7, 28, 22, 56, 56): [201.0, 201.0, 261.0, 261.0], datetime.datetime(2022, 7, 28, 23, 11, 55): [201.0, 261.0, 261.0, 157.0], datetime.datetime(2022, 7, 28, 23, 26, 56): [261.0, 261.0, 157.0, 157.0], datetime.datetime(2022, 7, 28, 23, 41, 55): [261.0, 157.0, 157.0, 163.0], datetime.datetime(2022, 7, 28, 23, 56, 56): [157.0, 157.0, 163.0, 163.0], datetime.datetime(2022, 7, 29, 0, 11, 55): [157.0, 163.0, 163.0, 143.0], datetime.datetime(2022, 7, 29, 0, 26, 56): [163.0, 163.0, 143.0, 143.0], datetime.datetime(2022, 7, 29, 0, 41, 55): [163.0, 143.0, 143.0, 136.0], datetime.datetime(2022, 7, 29, 0, 56, 55): [143.0, 143.0, 136.0, 136.0], datetime.datetime(2022, 7, 29, 1, 11, 56): [143.0, 136.0, 136.0, 133.0], datetime.datetime(2022, 7, 29, 1, 26, 55): [136.0, 136.0, 133.0, 133.0], datetime.datetime(2022, 7, 29, 1, 41, 55): [136.0, 133.0, 133.0, 113.0], datetime.datetime(2022, 7, 29, 1, 56, 55): [133.0, 133.0, 113.0, 113.0], datetime.datetime(2022, 7, 29, 2, 11, 55): [133.0, 113.0, 113.0, 107.0], datetime.datetime(2022, 7, 29, 2, 26, 56): [113.0, 113.0, 107.0, 107.0], datetime.datetime(2022, 7, 29, 2, 41, 56): [113.0, 107.0, 107.0, 72.0], datetime.datetime(2022, 7, 29, 2, 56, 56): [107.0, 107.0, 72.0, 72.0], datetime.datetime(2022, 7, 29, 3, 11, 55): [107.0, 72.0, 72.0, 59.0], datetime.datetime(2022, 7, 29, 3, 26, 55): [72.0, 72.0, 59.0, 59.0], datetime.datetime(2022, 7, 29, 3, 41, 55): [72.0, 59.0, 59.0, 61.0], datetime.datetime(2022, 7, 29, 3, 56, 55): [59.0, 59.0, 61.0, 61.0], datetime.datetime(2022, 7, 29, 4, 11, 56): [59.0, 61.0, 61.0, 121.0], datetime.datetime(2022, 7, 29, 4, 26, 57): [61.0, 61.0, 121.0, 202.0], datetime.datetime(2022, 7, 29, 4, 41, 56): [61.0, 121.0, 202.0, 202.0], datetime.datetime(2022, 7, 29, 4, 56, 56): [121.0, 202.0, 202.0, 202.0], datetime.datetime(2022, 7, 29, 5, 11, 56): [202.0, 202.0, 202.0, 276.0], datetime.datetime(2022, 7, 29, 5, 26, 55): [202.0, 202.0, 276.0, 276.0], datetime.datetime(2022, 7, 29, 5, 41, 55): [202.0, 276.0, 276.0, 233.0], datetime.datetime(2022, 7, 29, 5, 56, 55): [276.0, 276.0, 233.0, 233.0], datetime.datetime(2022, 7, 29, 6, 11, 55): [276.0, 233.0, 233.0, 275.0], datetime.datetime(2022, 7, 29, 6, 26, 56): [233.0, 233.0, 275.0, 275.0], datetime.datetime(2022, 7, 29, 6, 41, 56): [233.0, 275.0, 275.0,  ...

# %%
models = [linear_model.LinearRegression(optimizer=optim.SGD(lr=lr)) for lr in [0.05, 0.02, 0.01, 0.005, 0.002, 0.0001]]


model = compose.Pipeline(
    ('features', compose.TransformerUnion(
        ('date_progress', compose.FuncTransformer(get_date_progress)),
        ('lags', compose.FuncTransformer(get_lag))
    )))

model += (
    get_hour | 
        feature_extraction.TargetAgg(
            by=['h'], how=stats.Mean()


))
model += (
    get_minute | 
        feature_extraction.TargetAgg(
            by=['m'], how=stats.Mean()


))

model |=  preprocessing.StandardScaler()
model |= linear_model.LinearRegression(intercept_lr=.1)


# model |=  model_selection.EpsilonGreedyRegressor(models, epsilon=0.025, decay=0.1, burn_in=100, seed=1)
# model |= tree.HoeffdingAdaptiveTreeRegressor(grace_period=100, leaf_prediction='adaptive', model_selector_decay=0.9, seed=0)
# model = preprocessing.TargetStandardScaler(regressor=model)

# %%
metric = metrics.MAE() + metrics.R2()
evaluate.progressive_val_score(stream.iter_csv('hospital_wait.csv', target = 'value', **params), model, metric, print_every=50)
# evaluate.progressive_val_score(stream.iter_csv('hospital_wait.csv', target = 'value', **params), dummy.StatisticRegressor(stats.Shift(1)), metric, print_every=50)
model.transform_one(x)
# Out:
# [50] MAE: 45.879082, R2: -0.004024
# [100] MAE: 36.566037, R2: 0.694548
# [150] MAE: 27.610535, R2: 0.818795
# [200] MAE: 23.715372, R2: 0.838152
# [250] MAE: 20.122645, R2: 0.860365
# [300] MAE: 18.389003, R2: 0.88454
# [350] MAE: 16.422354, R2: 0.912944
# [400] MAE: 15.160021, R2: 0.92184
# [450] MAE: 14.434028, R2: 0.92707
# [500] MAE: 13.822398, R2: 0.932736
# [550] MAE: 12.841361, R2: 0.938584
# [600] MAE: 12.427435, R2: 0.941154
# [650] MAE: 11.665425, R2: 0.946559
# [700] MAE: 10.994886, R2: 0.948179
# [750] MAE: 10.445997, R2: 0.951443
# [800] MAE: 9.965217, R2: 0.952663
# [850] MAE: 9.590534, R2: 0.956341
# [900] MAE: 9.162267, R2: 0.958786
# [950] MAE: 8.888767, R2: 0.961491
# [1,000] MAE: 8.593528, R2: 0.962387
# {'y_mean_by_m': -0.9807493324966388,
#  'y_mean_by_h': -1.2949853252408325,
#  'lag_1': -0.7824379451711704,
#  'lag_2': -0.7807918309726335,
#  'lag_3': -0.7347856615567347,
#  'lag_4': -0.7332484358217568,
#  'date': 1.8460647891520903}

# %%
from river import metrics
import matplotlib.pyplot as plt
import collections


queue = collections.deque([], 4)

def evaluate_model(model): 

    metric = metrics.Rolling(metrics.MAE(), 10)
    metric_b = metrics.Rolling(metrics.MAE(), 10)
    
    dates = []
    y_trues = []
    y_preds = []
    
    baseline = 0
    y_baseline = []
    for x, y in stream.iter_csv('hospital_wait.csv', target = 'value', **params):
        
        new_feats = {f"lag_{i}": v for i, v in enumerate(queue)}

        # copy of x
        x_ = dict(x)
        x_.update(new_feats)

        y_pred = model.predict_one(x_)
        model.learn_one(x_, y)

        queue.append(y)

        # Obtain the prior prediction and update the model in one go
        y_pred = model.predict_one(x)
        model.learn_one(x, y)

        # Update the error metric
        metric.update(y, y_pred)
        metric_b.update(y, baseline)
        
        # Store the true value and the prediction
        dates.append(x['time'])
        y_trues.append(y)
        y_preds.append(y_pred)
        y_baseline.append(baseline)
        baseline = y
        
    print(metric, metric_b)

    # Plot the results
    fig, ax = plt.subplots(figsize=(20, 6))
    ax.grid(alpha=0.75)
    ax.plot(dates, y_trues, lw=3, color='#2ecc71', alpha=800, label='Ground truth')
    ax.plot(dates, y_preds, lw=3, color='#e74c3c', alpha=800, label='Prediction')
    ax.plot(dates, y_baseline, lw=3, color='#e74c3c', alpha=800, label='Baseline')
    ax.legend()
    ax.set_title(metric)
evaluate_model(model)
# Out:
# MAE: 0.4934	(rolling 10) MAE: 4.	(rolling 10)
# C:\Users\This PC\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\This PC\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
def make_model(alpha):
    models = [linear_model.LinearRegression(optimizer=optim.SGD(lr=lr), loss=optim.losses.Quantile(alpha=alpha)) for lr in [0.05, 0.02, 0.01, 0.005, 0.002, 0.0001]]


    model = compose.Pipeline(
        ('features', compose.TransformerUnion(
            ('date_progress', compose.FuncTransformer(get_date_progress)),
            ('lags', compose.FuncTransformer(get_lag))
        )))

    model += (
        get_hour | 
            feature_extraction.TargetAgg(
                by=['h'], how=stats.Mean()


    ))
    # model += (
    #     get_minute | 
    #         feature_extraction.TargetAgg(
    #             by=['m'], how=stats.Mean()


    # ))

    model |=  preprocessing.StandardScaler()
    model |= preprocessing.TargetStandardScaler( 
        model_selection.UCBRegressor(
            models,
            delta=0.01, burn_in=100, seed=1
        )
    )
    return model

# %%
models = {
    'lower': make_model(alpha=0.05),
    'center': make_model(alpha=0.5),
    'upper': make_model(alpha=0.95)
}

dates = []
y_trues = []
y_preds = {
    'lower': [],
    'center': [],
    'upper': []
}

for x, y in stream.iter_csv('hospital_wait.csv', target = 'value', **params):
    y_trues.append(y)
    dates.append(x['time'])

    for name, model in models.items():
        y_preds[name].append(model.predict_one(x))
        model.learn_one(x, y)

    # Update the error metric
    metric.update(y, y_preds['center'][-1])

# Plot the results
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid(alpha=0.75)
ax.plot(dates, y_trues, lw=3, color='#2ecc71', alpha=0.8, label='Truth')
ax.plot(dates, y_preds['center'], lw=3, color='#e74c3c', alpha=0.8, label='Prediction')
ax.fill_between(dates, y_preds['lower'], y_preds['upper'], color='#e74c3c', alpha=0.3, label='Prediction interval')
ax.legend()
ax.set_title(metric);
